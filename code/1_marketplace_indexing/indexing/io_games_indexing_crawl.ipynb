# %%
import pandas as pd
import re
import json
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load internet top lists

# %% [markdown]
# Alexa global top 1 Million websites

# %%
#Alexa top1M
df_alexa= pd.read_csv("./internet_top_lists/alexa-top-1m.txt", header = None)
df_alexa
# df_alexa[1] = df_alexa[0]
# df_alexa[0] = df_alexa.index + 1
#search by str.contain
 #  df_alexa[df_alexa[1].str.contains('poki')].head()
df_alexa.columns = ['Rank', 'Website']
df_alexa.head(5)
# Out:
#    Rank       Website
# 0     1    google.com
# 1     2   youtube.com
# 2     3     baidu.com
# 3     4  facebook.com
# 4     5  bilibili.com

# %% [markdown]
# Majestic global top 1 Million domains (based on subnets)

# %%
#Majestic top1M
df_majestic = pd.read_csv("./internet_top_lists/majestic_million.csv")
df_majestic.head()
# Out:
#    GlobalRank  TldRank         Domain  TLD  RefSubNets   RefIPs  \
# 0           1        1     google.com  com      504710  2632872
# 1           2        2   facebook.com  com      503645  2785660
# 2           3        3    youtube.com  com      455709  2272575
# 3           4        4    twitter.com  com      447261  2246848
# 4           5        5  instagram.com  com      379059  1833615
#
#       IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  PrevRefSubNets  \
# 0     google.com     com               1            1          505887
# 1   facebook.com     com               2            2          504788
# 2    youtube.com     com               3            3          456951
# 3    twitter.com     com               4            4          448381
# 4  instagram.com     com               5            5          380176
#
#    PrevRefIPs
# 0     2644923
# 1     2797727
# 2     2283594
# 3     2256993
# 4     1842150

# %% [markdown]
# Cisco Umbrella global top 1 Million domains (based on DNS)

# %%
#Cisco Umbrella top 1M
df_umbrella = pd.read_csv("./internet_top_lists/cisco_umbrella_top1M.csv", header=None)
df_umbrella.columns = ['Rank', 'Domain']
df_umbrella.head()
# Out:
#    Rank                  Domain
# 0     1             netflix.com
# 1     2         ftl.netflix.com
# 2     3    prod.ftl.netflix.com
# 3     4  api-global.netflix.com
# 4     5     ichnaea.netflix.com

# %% [markdown]
# Quantcast top 1M websites (US-ONLY!)

# %%
#Quantcast top 1M US
df_quantcast = pd.read_csv("./internet_top_lists/Quantcast-top1M-USonly.txt", sep='\t')
df_umbrella.columns = ['Rank', 'Website']
df_quantcast
# Out:
#           Rank               Site
# 0            1         google.com
# 1            2       facebook.com
# 2            3         amazon.com
# 3            4        youtube.com
# 4            5        twitter.com
# ...        ...                ...
# 467517  464839  zerowastenerd.com
# 467518  464839        zevyjoy.com
# 467519  464839    zombietechs.com
# 467520  464839      zonacooks.com
# 467521  464839          zowes.com
#
# [467522 rows x 2 columns]

# %% [markdown]
# ### Parse "io games" search results (json to DataFrame)
#
# A score is added, based on ranking and prominence in search results
#
# Every time a website is found in search results, **do:** $score = score + x$
#
# where $x \in [0,1.0]$ (x=1 if website is the first search result, x=0 if it is the last one)

# %%
#convert json search results in list of tuples 
def json_to_result_tuples(json_file, engine, lan="english"):
    results_from_json = []
    with open(json_file) as f:
        data = json.load(f)
    n_res = len(data)
    for tup in data:
        #extract website
        if tup['url'][0:8] == "https://":
            website = tup['url'].split("https://")[1].split("/")[0]
        elif tup['url'][0:7] == "http://":
            website = tup['url'].split("http://")[1].split("/")[0]
        else:
            continue

        #add tuple (add "score" value e.g., rank1-->100, rank2-->99, etc..)
        results_from_json.append ({'engine':engine,
                            'keywords': "io games",
                            'language':lan,
                            'website':website, 
                            'search_rank':tup['rank'],
                            'search_score': 1-tup['rank']/n_res}) #relative
    return results_from_json

# %% [markdown]
# #### Include one of the following:

# %% [markdown]
# #### Case 1: Google only, top30 languages, 100 results per language

# %%
res_tuples = []

# include google, different languages, no proxy
f_list = %sx ls ./output/google*.json
for f_json in f_list:
    lan = f_json.split("google_")[1].split("_")[0]
    res_tuples.extend(json_to_result_tuples(f_json, "google", lan))
    
#create dataframe from result tuples
df_res = pd.DataFrame(res_tuples)

#website with top score
df_topscore = df_res.groupby("website")['search_score'].sum().sort_values(ascending=False)

df_res
# Out:
#       engine  keywords    language                   website  search_rank  \
# 0     google  io games      arabic         www.pacogames.com            1
# 1     google  io games      arabic         www.pacogames.com            2
# 2     google  io games      arabic            suppsington.ml            3
# 3     google  io games      arabic             www.dm.gov.ae            4
# 4     google  io games      arabic          www.ar.obfog.com            5
# ...      ...       ...         ...                       ...          ...
# 5371  google  io games  vietnamese  yeoldeenglishflyshop.com           95
# 5372  google  io games  vietnamese         vi.aliexpress.com           96
# 5373  google  io games  vietnamese      listfortmcmurray.com           97
# 5374  google  io games  vietnamese                topgame.vn           98
# 5375  google  io games  vietnamese              trochoi8.com           99
#
#       search_score
# 0         0.989899
# 1         0.979798
# 2         0.969697
# 3         0.959596
# 4         0.949495
# ...            ...
# 5371      0.040404
# 5372      0.030303
# 5373      0.020202
# 5374      0.010101
# 5375      0.000000
#
# [5376 rows x 6 columns]

# %%
res_tuples = []

# include google, different languages, no proxy
f_list = %sx ls ./output/baidu*.json
for f_json in f_list:
    lan = f_json.split("baidu_")[1].split("_")[0]
    res_tuples.extend(json_to_result_tuples(f_json, "baidu", lan))
    
#create dataframe from result tuples
df_res = pd.DataFrame(res_tuples)

#website with top score
df_topscore = df_res.groupby("website")['search_score'].sum().sort_values(ascending=False)

df_res
# Out:
#      engine  keywords    language             website  search_rank  \
# 0     baidu  io games      arabic      www.100try.com            1
# 1     baidu  io games      arabic         tv.sohu.com            2
# 2     baidu  io games      arabic     www.chayiba.com            3
# 3     baidu  io games      arabic      www.iapolo.com            4
# 4     baidu  io games      arabic      www.iapolo.com            5
# ...     ...       ...         ...                 ...          ...
# 4980  baidu  io games  vietnamese       www.doc88.com            6
# 4981  baidu  io games  vietnamese  space.bilibili.com            7
# 4982  baidu  io games  vietnamese      cn.linguee.com            8
# 4983  baidu  io games  vietnamese      blog.51cto.com            9
# 4984  baidu  io games  vietnamese    zhidao.baidu.com           10
#
#       search_score
# 0             0.99
# 1             0.98
# 2             0.97
# 3             0.96
# 4             0.95
# ...            ...
# 4980          0.40
# 4981          0.30
# 4982          0.20
# 4983          0.10
# 4984          0.00
#
# [4985 rows x 6 columns]

# %%
res_tuples = []

# include google, different languages, no proxy
f_list = %sx ls ./output/ask.com*.json
for f_json in f_list:
    lan = f_json.split("ask.com_")[1].split("_")[0]
    res_tuples.extend(json_to_result_tuples(f_json, "ask.com", lan))
    
#create dataframe from result tuples
df_res = pd.DataFrame(res_tuples)

#website with top score
df_topscore = df_res.groupby("website")['search_score'].sum().sort_values(ascending=False)

df_res
# Out:
#       engine  keywords language                    website  search_rank  \
# 0    ask.com  io games  english           www.askmoney.com            1
# 1    ask.com  io games  english           www.askmoney.com            2
# 2    ask.com  io games  english  www.questionsanswered.net            3
# 3    ask.com  io games  english    www.freeonlinegames.com            4
# 4    ask.com  io games  english           www.arkadium.com            5
# ..       ...       ...      ...                        ...          ...
# 222  ask.com  io games   telugu              websetnet.net           29
# 223  ask.com  io games   telugu             www.ntnews.com           30
# 224  ask.com  io games   telugu   www.actualidadgadget.com           31
# 225  ask.com  io games   telugu          chrome.google.com           32
# 226  ask.com  io games   telugu         tryengineering.org           33
#
#      search_score
# 0        0.989011
# 1        0.978022
# 2        0.967033
# 3        0.956044
# 4        0.945055
# ..            ...
# 222      0.121212
# 223      0.090909
# 224      0.060606
# 225      0.030303
# 226      0.000000
#
# [227 rows x 6 columns]

# %%
res_tuples = []

# include google, different languages, no proxy
f_list = %sx ls ./output/bing*.json
for f_json in f_list:
    lan = f_json.split("bing_")[1].split("_")[0]
    res_tuples.extend(json_to_result_tuples(f_json, "bing", lan))
    
#create dataframe from result tuples
df_res = pd.DataFrame(res_tuples)

#website with top score
df_topscore = df_res.groupby("website")['search_score'].sum().sort_values(ascending=False)

df_res
# Out:
#       engine  keywords    language                           website  \
# 0       bing  io games      arabic                       mawdoo3.com
# 1       bing  io games      arabic                          sabq.org
# 2       bing  io games      arabic                  www.facebook.com
# 3       bing  io games      arabic  healthawarenessalaa.blogspot.com
# 4       bing  io games      arabic                         apkgk.com
# ...      ...       ...         ...                               ...
# 16350   bing  io games  vietnamese                  www.pinterest.ca
# 16351   bing  io games  vietnamese                 www.microsoft.com
# 16352   bing  io games  vietnamese                vi.m.wikipedia.org
# 16353   bing  io games  vietnamese                vi.m.wikipedia.org
# 16354   bing  io games  vietnamese                      gamevivu.com
#
#        search_rank  search_score
# 0                1          0.99
# 1                2          0.98
# 2                3          0.97
# 3                4          0.96
# 4                5          0.95
# ...            ...           ...
# 16350           96          0.04
# 16351           97          0.03
# 16352           98          0.02
# 16353           99          0.01
# 16354          100          0.00
#
# [16355 rows x 6 columns]

# %% [markdown]
# #### Case 2: Google only, English only, 423 results
#
# (manual search, as no more than 100 results can be requested by crafting the request url)

# %%
res_tuples = []
f_json = "./output/google_english_423__res.json"

lan = f_json.split("google_")[1].split("_")[0]
res_tuples.extend(json_to_result_tuples(f_json, "google", lan))
    
#create dataframe from result tuples
df_res = pd.DataFrame(res_tuples)

#website with top score
df_topscore = df_res.groupby("website")['search_score'].sum().sort_values(ascending=False)

df_res
# Out:
#      engine  keywords language                  website  search_rank  \
# 0    google  io games  english                 poki.com            1
# 1    google  io games  english       www.crazygames.com            2
# 2    google  io games  english            www.kiloo.com            3
# 3    google  io games  english            www.quora.com            4
# 4    google  io games  english          www.io-games.io            5
# ..      ...       ...      ...                      ...          ...
# 418  google  io games  english              grad.center          419
# 419  google  io games  english             padsreds.com          420
# 420  google  io games  english              mktabah.com          421
# 421  google  io games  english  cacti.forestjournal.org          422
# 422  google  io games  english            datameetup.es          423
#
#      search_score
# 0        0.997636
# 1        0.995272
# 2        0.992908
# 3        0.990544
# 4        0.988180
# ..            ...
# 418      0.009456
# 419      0.007092
# 420      0.004728
# 421      0.002364
# 422      0.000000
#
# [423 rows x 6 columns]

# %% [markdown]
# #### Case 2: Google+Bing+Baidu+Yahoo, English only, query for 1000 res

# %%
res_tuples = []

#add google (manual search)
f_json = "./output/google_english_423__res.json"
res_tuples.extend(json_to_result_tuples(f_json, "google", "english"))

#add yahoo, bing, baidu
for engine in ["baidu", "bing", "yahoo"]:
    f_json = "./output/" + engine + "_english_1000__res.json"
    res_tuples.extend(json_to_result_tuples(f_json, engine, "english"))

#create dataframe from result tuples
df_res = pd.DataFrame(res_tuples)

#website with top score (based frequency+ranking in search results)
df_topscore = df_res.groupby("website")['search_score'].sum().sort_values(ascending=False)

df_res
# Out:
#       engine  keywords language                  website  search_rank  \
# 0     google  io games  english                 poki.com            1
# 1     google  io games  english       www.crazygames.com            2
# 2     google  io games  english            www.kiloo.com            3
# 3     google  io games  english            www.quora.com            4
# 4     google  io games  english          www.io-games.io            5
# ...      ...       ...      ...                      ...          ...
# 3033   yahoo  io games  english   teamthetagames.itch.io          836
# 3034   yahoo  io games  english   vollkorn-games.itch.io          837
# 3035   yahoo  io games  english     throughgames.itch.io          838
# 3036   yahoo  io games  english      razek-games.itch.io          840
# 3037   yahoo  io games  english  epicpersongames.itch.io          842
#
#       search_score
# 0         0.997636
# 1         0.995272
# 2         0.992908
# 3         0.990544
# 4         0.988180
# ...            ...
# 3033      0.007126
# 3034      0.005938
# 3035      0.004751
# 3036      0.002375
# 3037      0.000000
#
# [3038 rows x 6 columns]

# %% [markdown]
# #### Case 3: Google+Bing+Baidu+Yahoo, top30 languages, all available res in ./output

# %%
res_tuples = []

#more engines, different languages, and no proxy
f_list = %sx ls ./output/*.json
for f_json in f_list:
    engine = f_json.split('_')[0]
    lan = f_json.split('_')[1]
    res_tuples.extend(json_to_result_tuples(f_json, engine, lan))
    
#create dataframe from result tuples
df_res = pd.DataFrame(res_tuples)

#website with top score (based frequency+ranking in search results)
df_topscore = df_res.groupby("website")['search_score'].sum().sort_values(ascending=False)

df_res
# Out:
#                  engine  keywords    language  \
# 0      ./output/ask.com  io games     english
# 1      ./output/ask.com  io games     english
# 2      ./output/ask.com  io games     english
# 3      ./output/ask.com  io games     english
# 4      ./output/ask.com  io games     english
# ...                 ...       ...         ...
# 28721    ./output/yahoo  io games  vietnamese
# 28722    ./output/yahoo  io games  vietnamese
# 28723    ./output/yahoo  io games  vietnamese
# 28724    ./output/yahoo  io games  vietnamese
# 28725    ./output/yahoo  io games  vietnamese
#
#                                                  website  search_rank  \
# 0                                       www.askmoney.com            1
# 1                                       www.askmoney.com            2
# 2                              www.questionsanswered.net            3
# 3                                www.freeonlinegames.com            4
# 4                                       www.arkadium.com            5
# ...                                                  ...          ...
# 28721                                  www.hellokids.com           73
# 28722                                         www.y8.net           75
# 28723                          slitherio.vi.softonic.com           76
# 28724      bba-game-studio-shooting-games.vn.aptoide.com           94
# 28725  free-games-naruto-animes-fan-tro-choi-mien-phi...           95
#
#        search_score
# 0          0.989011
# 1          0.978022
# 2          0.967033
# 3          0.956044
# 4          0.945055
# ...             ...
# 28721      0.231579
# 28722      0.210526
# 28723      0.200000
# 28724      0.010526
# 28725      0.000000
#
# [28726 rows x 6 columns]

# %% [markdown]
# ### Annotate  websites in google searches against alexa top1M

# %%
def get_alexa_rank(website):
    #some websites may or may not appear with "www."
    alexa_rank = None
    if website[0:4] == "www.":
        df_alexa_select = df_alexa[df_alexa["Website"] == (website.split("www.")[1])].values
        if len(df_alexa_select)>0:
            alexa_rank = df_alexa_select[0][0]
        else:
            df_alexa_select = df_alexa[df_alexa["Website"] == website].values
            if len(df_alexa_select)>0:
                alexa_rank = df_alexa_select[0][0]
    else:
        df_alexa_select = df_alexa[df_alexa["Website"]==website].values
        if len(df_alexa_select)>0:
            alexa_rank = df_alexa_select[0][0]
        else:
            df_alexa_select = df_alexa[df_alexa["Website"] == "www."+website].values
            if len(df_alexa_select)>0:
                alexa_rank = df_alexa_select[0][0]
    return alexa_rank

def get_umbrella_rank(domain):
    #some domains may or may not appear with "www." 
    umbrella_rank = None
    if domain[0:4] == "www.":
        df_umbrella_select = df_umbrella[df_umbrella["Domain"] == (domain.split("www.")[1])].values
        if len(df_umbrella_select)>0:
            umbrella_rank = df_umbrella_select[0][0]
        else:
            df_umbrella_select = df_umbrella[df_umbrella["Domain"] == domain].values
            if len(df_umbrella_select)>0:
                umbrella_rank = df_umbrella_select[0][0]
    else:
        df_umbrella_select = df_umbrella[df_umbrella["Domain"] == domain].values
        if len(df_umbrella_select)>0:
            umbrella_rank = df_umbrella_select[0][0]
        else:
            df_umbrella_select = df_umbrella[df_umbrella["Domain"] == "www."+domain].values
            if len(df_umbrella_select)>0:
                umbrella_rank = df_umbrella_select[0][0]
    return umbrella_rank

def get_quantcast_rank(site):
    #some sites may or may not appear with "www."
    quantcast_rank = None
    if site[0:4] == "www.":
        df_quantcast_select = df_quantcast[df_quantcast["Site"] == (site.split("www.")[1])].values
        if len(df_quantcast_select)>0:
            quantcast_rank = df_quantcast_select[0][0]
        else:
            df_quantcast_select = df_quantcast[df_quantcast["Site"] == site].values
            if len(df_quantcast_select)>0:
                quantcast_rank = df_quantcast_select[0][0]
    else:
        df_quantcast_select = df_quantcast[df_quantcast["Site"]==site].values
        if len(df_quantcast_select)>0:
            quantcast_rank = df_quantcast_select[0][0]
        else:
            df_quantcast_select = df_quantcast[df_quantcast["Site"] == "www."+site].values
            if len(df_quantcast_select)>0:
                quantcast_rank = df_quantcast_select[0][0]
    return quantcast_rank

def get_majestic_rank(domain):
    #some domains may or may not appear with "www."
    majestic_rank = None
    if domain[0:4] == "www.":
        df_majestic_select = df_majestic[df_majestic["Domain"] == (domain.split("www.")[1])]['GlobalRank'].values
        if len(df_majestic_select)>0:
            majestic_rank = df_majestic_select[0]
        else:
            df_majestic_select = df_majestic[df_majestic["Domain"] == domain]['GlobalRank'].values
            if len(df_majestic_select)>0:
                majestic_rank = df_majestic_select[0]
    else:
        df_majestic_select = df_majestic[df_majestic["Domain"]==domain]['GlobalRank'].values
        if len(df_majestic_select)>0:
            majestic_rank = df_majestic_select[0]
        else:
            df_majestic_select = df_majestic[df_majestic["Domain"] == "www."+domain]['GlobalRank'].values
            if len(df_majestic_select)>0:
                majestic_rank = df_majestic_select[0]
    return majestic_rank

# %% [markdown]
# Annotate ranking from internet top lists (**this might take a few minutes**)

# %%
website
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-abc9e7e9135d> in <module>
# ----> 1 website
#
# NameError: name 'website' is not defined

# %%
combo_data = []

for website, score in zip(df_topscore.index, df_topscore):
    #each of these return nan if no match in the top1M list
    alexa_rank = get_alexa_rank(website)
    umbrella_rank = get_umbrella_rank(website)
    majestic_rank = get_majestic_rank(website)
    quantcast_rank = get_quantcast_rank(website)
    combo_data.append({'website':website, 
                       'search_score': score, 
                       'alexa_rank': alexa_rank, 
                       'majestic_rank': majestic_rank, 
                       'umbrella_rank': umbrella_rank , 
                       'quantcast_rank': quantcast_rank})
#     plt.scatter(alexa_rank, score)
# plt.xlabel("Alexa rank")
# plt.ylabel("search score)")
# plt.xscale("log")
# plt.yscale("log")
# plt.show()

#combo search_score + internet toplist ranking 
df_combo = pd.DataFrame(combo_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/notebook/jupyterenv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/notebook/jupyterenv/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/notebook/jupyterenv/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Domain'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-dca365f187b5> in <module>
#       4     #each of these return nan if no match in the top1M list
#       5     alexa_rank = get_alexa_rank(website)
# ----> 6     umbrella_rank = get_umbrella_rank(website)
#       7     majestic_rank = get_majestic_rank(website)
#       8     quantcast_rank = get_quantcast_rank(website)
#
# <ipython-input-17-d079261a7362> in get_umbrella_rank(domain)
#      24     umbrella_rank = None
#      25     if domain[0:4] == "www.":
# ---> 26         df_umbrella_select = df_umbrella[df_umbrella["Domain"] == (domain.split("www.")[1])].values
#      27         if len(df_umbrella_select)>0:
#      28             umbrella_rank = df_umbrella_select[0][0]
#
# ~/notebook/jupyterenv/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/notebook/jupyterenv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Domain'

# %%
df_combo['is_marketplace'] = 0
df_combo['is_iogame'] = 0
df_combo.sort_values('alexa_rank').to_csv("top_results_new.csv",)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ee0e2b09920e> in <module>
# ----> 1 df_combo['is_marketplace'] = 0
#       2 df_combo['is_iogame'] = 0
#       3 df_combo.sort_values('alexa_rank').to_csv("top_results_new.csv",)
#
# NameError: name 'df_combo' is not defined

# %% [markdown]
# #### Define a set of "prominent" websites based on (i) alexa rank and/or (ii) frequency+ranking in search results
#
# ##### TODO: discuss criteria

# %%
#search score + alexa ranking


#e.g., select based on some thresholds on rank and score
# df_combo = df_combo[(df_combo['search_score']>10) & (df_combo['alexa_rank']<10000)].sort_values('alexa_rank')

#e.g., select based on alexa rank only
# df_combo = df_combo[(df_combo['alexa_rank']<1e5)].sort_values('alexa_rank')

#e.g., select all, order by alexa rank
df_combo = df_combo.sort_values('alexa_rank')
print(len(df_combo))
#Manual checking of websites to discover io games marketplaces can start from here:
print("Website Alexa_rank")
for x,y in df_combo.iterrows():
    print(y['website'], y['alexa_rank'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e1b033bcecc1> in <module>
#       9
#      10 #e.g., select all, order by alexa rank
# ---> 11 df_combo = df_combo.sort_values('alexa_rank')
#      12 print(len(df_combo))
#      13 #Manual checking of websites to discover io games marketplaces can start from here:
#
# NameError: name 'df_combo' is not defined

# %%
import requests
"""
old, replaced 
"""
#GOOGLE
r = requests.get('https://www.crazygames.com/c/io', auth=('user', 'pass'))
print(r.text)

http_urls = re.findall('http://.+?/',r.text)
http_urls = [x for x in http_urls if (x[-2].isalpha() or x[-2].isdigit()) and ' ' not in x]

https_urls = re.findall('https://.+?/',r.text)
https_urls = [x for x in https_urls if (x[-2].isalpha() or x[-2].isdigit()) and ' ' not in x]

urls = list(set().union(http_urls, https_urls)) 
print("%d urls collected" % len(urls))
urls

#https://edmundmartin.com/scraping-baidu-with-python/
# Out:
# <!DOCTYPE html><html lang="en" dir="ltr"><head><meta charSet="utf-8" /><meta name="viewport" content="user-scalable=no, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, width=device-width, height=device-height" /><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-312835820"></script><script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag() {dataLayer.push(arguments)};
#   </script><title>.io Games - Play .io Games on CrazyGames</title><meta http-equiv="Accept-CH" content="DPR" /><meta name="description" content="We collected 412 of the best free online .io games. These games include browser games for both your computer and mobile devices, as well as apps for your Android and iOS phones and tablets. They include new .io games such as  and top .io games such as Shell Shockers, Smash Karts, and Rocket Bot Royale." /><link rel="canonical" href="https://www.crazygames.com/c/io" /><link rel="alternate" hrefLang="nl" href="https://www.crazygames.nl/categorie/io" /><link rel="alternate" hrefLang="en" href="https://www.crazygames.com/c/io" /><link rel="alternate" hrefLang="it" href="https://it.crazygames.com/categoria/io" /><link rel="alternate" hrefLang="es" href="https://www.1001juegos.com/categoria/io" /><link rel="alternate" hrefLang="id" href="https://www.crazygames.co.id/k/io" /><link rel="alternate" hrefLang="fr" href="https://www.crazygames.fr/c/io" /><link rel="alternate" hrefLang="pt" href="https://www.crazygames.com.br/c/io" /><link rel="alternate" hrefLang="ru" href="https://www.crazygames.ru/c/io" /><link rel="alternate" hrefLang="uk" href="https://www.crazygames.com.ua/c/io" /><link rel="alternate" hrefLang="nb" href="https://www.crazygames.no/c/io" /><link rel="alternate" hrefLang="ro" href="https://www.crazygames.ro/c/io" /><link rel="alternate" hrefLang="fi" href="https://www.crazygames.fi/c/io" /><link rel="alternate" hrefLang="sv" href="https://www.crazygames.se/c/io" /><link rel="alternate" hrefLang="de" href="https://de.crazygames.com/c/io" /><link rel="alternate" hrefLang="pl" href="https://pl.crazygames.com/c/io" /><link rel="alternate" hrefLang="el" href="https://gr.crazygames.com/k/io" /><link rel="alternate" hrefLang="da" href="https://www.crazygames.dk/c/io" /><link rel="alternate" hrefLang="cs" href="https://www.crazygames.cz/c/io" /><link rel="alternate" hrefLang="hu" href="https://www.crazygames.hu/c/io" /><link rel="alternate" hrefLang="tr" href="https://tr.crazygames.com/k/io" /><link rel="alternate" hrefLang="ar" href="https://ar.crazygames.com/c/io" /><link rel="alternate" hrefLang="vi" href="https://www.crazygames.com.vn/c/io" /><link rel="alternate" hrefLang="th" href="https://th.crazygames.com/%E0%B8%AB%E0%B8%A1%E0%B8%A7%E0%B8%94%E0%B8%AB%E0%B8%A1%E0%B8%B9%E0%B9%88/io" /><link rel="alternate" href="https://www.crazygames.com/c/io" hrefLang="x-default" /><meta name="theme-color" content="#6937B9" /><meta name="HandheldFriendly" content="true" /><meta name="mobile-web-app-capable" content="yes" /><meta name="apple-mobile-web-app-capable" content="yes" /><meta name="apple-mobile-web-app-status-bar-style" content="default" /><link rel="apple-touch-icon" href="https://images.crazygames.com/favicons/apple-icon.png?auto=format,compress&amp;q=75&amp;cs=strip&amp;ch=DPR&amp;w=120&amp;h=120&amp;fit=crop&amp;crop=entropy" /><link rel="apple-touch-icon" sizes="152x152" href="https://images.crazygames.com/favicons/apple-icon.png?auto=format,compress&amp;q=75&amp;cs=strip&amp;ch=DPR&amp;w=152&amp;h=152&amp;fit=crop&amp;crop=entropy" /><link rel="apple-touch-icon" sizes="167x167" href="https://images.crazygames.com/favicons/apple-icon.png?auto=format,compress&amp;q=75&amp;cs=strip&amp;ch=DPR&amp;w=167&amp;h=167&amp;fit=crop&amp;crop=entropy" /><link rel="apple-touch-icon" sizes="180x180" href="https://images.crazygames.com/favicons/apple-icon.png?auto=format,compress&amp;q=75&amp;cs=strip&amp;ch=DPR&amp;w=180&amp;h=180&amp;fit=crop&amp;crop=entropy" /><link rel="icon" href="https://images.crazygames.com/favicons/favicon-32x32.png?auto=format,compress&amp;q=75&amp;cs=strip&amp;ch=DPR&amp;w=32&amp;h=32&amp;fit=crop&amp;crop=entropy" sizes="32x32" /><link rel="icon" href="https://images.crazygames.com/favicons/apple-icon-57x57.png?auto=format,compress&amp;q=75&amp;cs=strip&amp;ch=DPR&amp;w=57&amp;h=57&amp;fit=crop&amp;crop=entropy" sizes="57x57" /><link rel="icon" href="https://imag ...
#             (function(i,s,r,a,m){
#               i['GoogleAnalyticsObject']=r;
#               i[r]=i[r]||function(){
#                 ( i[r].q=i[r].q||[]).push(arguments)},
#                   i[r].l=1*new Date();
#             })
#             (window,document,'ga');</script><main style="pointer-events:auto" class="css-h47494"><div style="z-index:11"><header class="MuiPaper-root MuiPaper-elevation MuiPaper-elevation4 MuiAppBar-root MuiAppBar-colorPrimary MuiAppBar-positionFixed mui-fixed css-rymuei" id="czyHeader"><div class="MuiToolbar-root MuiToolbar-gutters MuiToolbar-regular css-1d72wmq"><div id="czyLogo" class="css-br7s82"><div class="css-1upw0fy"><div class="css-1gbydz5"><a href="https://www.crazygames.com/"><div class="css-1xgdpvb"><div class="css-15yrdju"><svg viewBox="0 0 26 29" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
.9021-.0786-.3377.1684-.687.3345-1.0455.5224l-1.0506.5164a22.9589 22.9589 0 001.5944.0554c3.054 0 5.501-.5439 7.428-1.6548"></path></g></svg></div><div locale="en-US" class="css-1gikcxh"></div></div></a></div><div class="css-15p2npx"><svg class="MuiSvgIcon-root MuiSvgIcon-fontSizeMedium css-vubbuv" focusable="false" viewBox="0 0 24 24" aria-hidden="true" data-testid="KeyboardArrowDownIcon" style="display:block;height:auto;width:auto"><path d="M7.41 8.59 12 13.17l4.59-4.58L18 10l-6 6-6-6 1.41-1.41z"></path></svg></div></div></div><nav class="MuiGrid-root MuiGrid-container MuiGrid-spacing-xs-undefined css-1b1jvye"><div class="MuiGrid-root MuiGrid-item css-jpkeok"><div class="MuiGrid-root MuiGrid-container MuiGrid-spacing-xs-undefined css-1ece03m"><div class="MuiGrid-root MuiGrid-item css-1wxaqej"><a href="https://www.crazygames.com/" class="css-19po32"><div class="M ...
#       0-.285-.113h-.014a.414.414 0 0 0-.352.218l-1.506 2.773-4.25-11.05 11.05 4.25-2.773
#       1.497a.418.418 0 0 0-.166.566m4.427 3.269a.413.413 0 0 1-.001.597l-2.36 2.351a.415.415
#       0 0 1-.586 0l-3.376-3.367-1.665 3.074a.416.416 0 0 1-.755-.051L5.956 6.49a.414.414 0
#       0 1 .327-.57h.001c.071-.01.142 0 .208.026L19.26 10.86a.415.415 0 0 1 .251.506.415.415
#       0 0 1-.2.249l-3.074 1.673 3.366 3.359zM7.64 4.722a.417.417 0 0 1-.417-.416V.416a.417.417
#       0 0 1 .834 0v3.89c0 .23-.187.416-.417.416zm2.821.553a.418.418 0 0 1-.299-.71l1.668-1.668a.413.413
#       0 0 1 .243-.127H12.125a.417.417 0 0 1 .298.716L10.758 5.15a.414.414 0
#       0 1-.298.125zM4.86 9.99a.404.404 0 0 1 .31.128.415.415 0 0 1-.012.589l-1.665 1.664a.413.413 0
#       0 1-.293.125h-.005a.416.416 0 0 1-.418-.413.415.415 0 0 1 .12-.297l1.667-1.668a.412.412 0
#       0 1 .244-.126l.02-.002h.032zm-2.24-6.785a.417.417 0 0 1 .212-.712l.025-.003h.033a.406.406 0
#       0 1 .329.131l1.663 1.664a.417.417 0 0 1-.005.592.417.417 0 0 1-.592-.007L2.62
#       3.206zm2.103 4.433c0 .23-.187.417-.416.417H.416a.417.417 0 0 1 0-.834h3.89c.23
#       0 .416.187.416.417z"></path></svg></div><div class="MuiGrid-root MuiGrid-item tabLabel css-1pw7ieg">Clicker</div></a></div><div class="MuiGrid-root MuiGrid-item css-1wxaqej"><a href="https://www.crazygames.com/c/driving" class="css-lutbk4"><div class="MuiGrid-root MuiGrid-item css-g5g5sw"><svg class="MuiSvgIcon-root MuiSvgIcon-fontSizeMedium czyIcon css-vubbuv" focusable="false" viewBox="0 0 24 24" aria-hidden="true" style="margin-top:7px"><path xmlns="http://www.w3.org/2000/svg" d="M7.8 15a2 2 0 01-4-.1 2 2 0 01-1.7-2v-1.7c0-1.1 1-2 2-2 .4 0 .8-.2 1-.5l.7-1.1c.4-.6 1-1 1.7-1h6c.4 0 .9.2 1.3.5L18 9.7c.2.2.5.3.7.3h.7c1.6 0 2.5 1.5 2.5 2.9a2 2 0 01-1.7 2 2 2 0 01-4 0H7.7zm0-.9h8.4a2 2 0 014 0c.5-.2.9-.6.9-1.2 0-.9-.5-2.1-1.7-2.1h-.7a2 2 0 01-1.2-.4l-3.3-2.6c-.2-.2-.4-.3-.7-.3h-6c-.4 0-.8.2-1 .6l-.7 1a2 2 0 01-1.6.9c-.7 0-1.3.5-1.3 1.2V13c0 .5.4 1 .9 1.2a2 2 0 014 0zm9.1.4a1.2 1.2 0 102.5 0 1.2 1.2 0 00-2.5 0zM5.8 15.8a1.2 1.2 0 100-2.5 1.2 1.2 0 000 2.4zm9.9-5.8c.2 0 .4.2.4.4s-.2.4-.4.4h-4.1a.4.4 0 01-.4-.4V8.7c0-.2.1-.4.4-.4.2 0 .4.2.4.4V10h3.7zm-5.8 0c.2 0 .4.2.4.4s-.2.4-.4.4H6.6a.4.4 0 01-.4-.4v-.2l.9-1.6c0-.2.3-.3.5-.2.2 0 .3.3.2.5l-.5 1h2.6zm3.3 1.6c.3 0 .4.2.4.4s-.1.5-.4.5h-.8c-.2 0-.4-.2-.4-.5s.2-.4.4-.4h.8z"></path></svg></div><div class="MuiGrid-root MuiGrid-item tabLabel css-1pw7ieg">Driving</div></a></div><div class="MuiGrid-root MuiGrid-item css-1wxaqej"><a href="https://www.crazygames.com/c/io" class="css-1bw7i0a"><div class="MuiGrid-root MuiGrid-item css-g5g5sw"><svg class="MuiSvgIcon-root MuiSvgIcon-fontSizeMedium czyIcon css-vubbuv" focusable="false" viewBox="0 0 24 24" aria-hidden="true" style="margin-top:11px"><path xmlns="http://www.w3.org/2000/svg" d="M8.7 1.1a7.6 7.6 0 000 15.2 7.5 7.5 0 006-3l-7-4.1a.6.6 0 010-1l7-4a7.5 7.5 0 00-6-3zm7.3 3a.6.6 0 01-.2.7l-6.7 4 6.7 3.8a.6.6 0 01.2.8 8.7 8.7 0 01-7.3 4A8.7 8.7 0 018.7 0 8.7 8.7 0 0116 4zM6 4.7a.6.6 0 101.2 0 .6.6 0 00-1.1 0zm.6 1.7a1.7 1.7 0 110-3.4 1.7 1.7 0 010 3.4zM15 8.7a.6.6 0 10-1.1 0 .6.6 0 001.1 0zM14.3 7a1.7 1.7 0 010 3.4 1.7 1.7 0 010-3.4zM19 8.7a.6.6 0 10-1.2 0 .6.6 0 001.2 0zM18.3 7a1.7 1.7 0 110 3.4 1.7 1.7 0 010-3.4z"></path></svg></div><div class="MuiGrid-root MuiGrid-item tabLabel css-1pw7ieg">.io</div></a></div><div class="MuiGrid-root MuiGrid-item css-1wxaqej"><a href="https://www.crazygames.com/c/puzzle" class="css-q2k07m"><div class="MuiGrid-root MuiGrid-item css-g5g5sw"><svg class="MuiSvgIcon-root MuiSvgIcon-fontSizeMedium czyIcon css-vubbuv" focusable="false" viewBox="0 0 24 24" aria-hidden="true" style="margin-top:5px"><path xmlns="http://www.w3.org/2000/svg" fill-rule="evenodd" d="M16.248 14.91c.572.594 1.34.921 2.165.921a2.97 2.97 0 0 0 1.345-.318.246.246 0
schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.crazygames.com/game/shellshockersio","name":"Shell Shockers","image":"https://images.crazygames.com/shellshockersio/20211202050253/shellshockersio-cover?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":2,"url":"https://www.crazygames.com/game/smash-karts","name":"Smash Karts","image":"https://images.crazygames.com/smash-karts/20201119155032/smash-karts-cover?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":3,"url":"https://www.crazygames.com/game/rocket-bot-royale","name":"Rocket Bot Royale","image":"https://images.crazygames.com/rocket-bot-royale/20220310095708/rocket-bot-royale-cover?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":4,"url":"http://www.crazygames.com/game/slitherio","name":"Slither.io","image":"https://images.crazygames.com/games/slitherio/cover-1587331280441.png?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":5,"url":"https://www.crazygames.com/game/stabfish-io","name":"Stabfish.io","image":"https://images.crazygames.com/stabfish-io/20220418192451/stabfish-io-cover?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":6,"url":"https://www.crazygames.com/game/zombsroyaleio","name":"Zombs Royale (ZombsRoyale.io)","image":"https://images.crazygames.com/games/zombsroyaleio/cover-1587299840102.png?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":7,"url":"https://www.crazygames.com/game/evowarsio","name":"EvoWars.io","image":"https://images.crazygames.com/games/evowarsio/cover-1586449813403.png?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":8,"url":"https://www.crazygames.com/game/merc-zone","name":"Merc Zone","image":"https://images.crazygames.com/games/merc-zone/cover-1614702000604.png?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":9,"url":"https://www.crazygames.com/game/voxiom-io","name":"Voxiom.io","image":"https://images.crazygames.com/voxiom-io/20201028120539/voxiom-io-cover?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":10,"url":"https://www.crazygames.com/game/minigiants-io","name":"MiniGiants.io","image":"https://images.crazygames.com/games/minigiants-io/cover-1584553354815.png?auto=format,compress&q=75&cs=strip"},{"@type":"ListItem","position":11,"url":"https://www.crazygames.com/game/stabfi ...
# <p>The first .io game was Agar.io. It was developed by Matheus Valadares in 2015 and gained significant popularity through the internet forum 4chan. The game revolves around cells that grow by eating agar and consuming other players. A few months after its release, the game was acquired by Miniclip, and a new game genre started to emerge based around the humble .io domain extension. </p>
# <p>The games that followed were focused on the growth mechanics that made Agar so popular, strengthening the idea of .io as a genre, not just a domain extension. <a target="_blank" href="http://www.crazygames.com/game/slitherio">Slither.io</a> was one of those games, with the same simple yet addictive concept but with snakes. There are now many grow games like <a target="_blank" href="https://www.crazygames.com/game/worms-zone">Worms Zone</a> and <a target="_blank" href="https://www.crazygames.com/game/wormateio">Wormate</a>, taking this concept further.</p>
# <h2>How to Play .IO Games</h2>
# <p>Many .io games are still based on growing your character by consuming food and slaying other players. Reach the top of the leaderboard by doing this repeatedly until you&#39;re the biggest! Most IO games feature:</p>
# <ul>
# <li>A large online multiplayer arena with a competitive leaderboard.</li>
# <li>Simple mechanics that make gameplay possible for anyone.</li>
# <li>Players that consume food, and often other players, to grow bigger.</li>
# <li>Mostly a ‘survival of the fittest’ free-for-all, sometimes with cooperative gameplay.</li>
# </ul>
# <h2>Newest .IO Games</h2>
# <p>.io games have grown substantially to include any and every type of game, from egg-shattering FPS games like <a target="_blank" href="https://www.crazygames.com/game/shellshockersio">Shell Shockers</a> to survival battle royale games like <a target="_blank" href="https://www.crazygames.com/game/voxiom-io">Voxiom</a> and <a target="_blank" href="https://www.crazygames.com/game/zombsroyaleio">Zombs Royale</a>. </p>
# <p>Some of the newest .io games include <a target="_blank" href="https://www.crazygames.com/game/smash-karts">Smash Karts</a> and the fantastically futuristic FPS game, <a target="_blank" href="https://www.crazygames.com/game/ev-io">Ev.io</a>. Both games were released in 2020 or 2021 and have already gained traction on CrazyGames. Check out <a target="_blank" href="https://www.crazygames.com/game/duckpark-io">DuckPark.io</a> and <a target="_blank" href="https://www.crazygames.com/game/rocket-bot-royale">Rocket Bot Royale </a>for two of the newest and most fantastic .io games available.</p>
# <p>Most .io games work seamlessly on mobile devices and desktop, since the controls are easy to learn. Browse the full collection on this page for all IO games, and be sure to check back regularly for the latest and greatest browser-based .io titles!</p></div><hr class="MuiDivider-root MuiDivider-fullWidth css-8b5xsp" /><script type="application/ld+json">{"@context":"https://schema.org","@type":"FAQPage","mainEntity":[{"@type":"Question","name":"What are the most popular .io Games?","acceptedAnswer":{"@type":"Answer","text":"<ol><li><a href=\"https://www.crazygames.com/game/shellshockersio\">Shell Shockers</a></li><li><a href=\"https://www.crazygames.com/game/smash-karts\">Smash Karts</a></li><li><a href=\"https://www.crazygames.com/game/rocket-bot-royale\">Rocket Bot Royale</a></li><li><a href=\"http://www.crazygames.com/game/slitherio\">Slither.io</a></li><li><a href=\"https://www.crazygames.com/game/stabfish-io\">Stabfish.io</a></li><li><a href=\"https://www.crazygames.com/game/zombsroyaleio\">Zombs Royale (ZombsRoyale.io)</a></li><li><a href=\"https://www.crazygames.com/game/evowarsio\">EvoWars.io</a></li><li><a href=\"https://www.crazygames.com/game/merc-zone\">Merc Zone</a></li><li><a href=\"https://www.crazygames.com/game/minigiants-io\">MiniGiants.io</a></li><li><a href=\"https://www.crazygames.com/game/voxiom-io\">Voxiom.io</a></li></ol>"}},{"@type":"Question","name":"What are the best .io Games to play on mobile phones and tablets?","acceptedAnswer":{"@type":"Answer","text":"<ol><li><a href=\"https://www.crazygames.com/game/bloxdhop-io\">Bloxd.io</a></li><li><a href=\"https://www.crazygames.com/game/flyordieio\">EvoWorld.io (FlyOrDie.io)</a></li><li><a href=\"https://www.crazygames.com/game/evowarsio\">EvoWars.io</a></li><li><a href=\"https://www.crazygames.com/game/minigiants-io\">MiniGiants.io</a></li><li><a href=\"https://www.crazygames.com/game/territorial-io\">Territorial.io</a></li></ol>"}},{"@type":"Question","name":"What are .io Games?","acceptedAnswer":{"@type":"Answer","text":"<p>IO games are real-time online games you can play in your web browser for free. The most common theme among .io games is online multiplayer. Besides that, these games are mostly based on the domain extension .io, which stands for ‘Indian Ocean.’ The top level domain extension is popular with software engineers since IO is short for &#39;Input / Output&#39;, a common term in computing.</p>"}}]}</script><h2>FAQ</h2><h3>What are the most popular .io Games?</h3><ol><li><a href="https://www.crazygames.com/game/shellshockersio">Shell Shockers</a></li><li><a href="https://www.crazygames.com/game/smash-karts">Smash Karts</a></li><li><a href="https://www.crazygames.com/game/rocket-bot-royale">Rocket Bot Royale</a></li><li><a href="http://www.crazygames.com/game/slitherio">Slither.io</a></li><li><a href="https://www.crazygames.com/game/stabfish-io">Stabfish.io</a></li><li><a href="https://www.crazygames.com/game/zombsroyaleio">Zombs Royale (ZombsRoyale.io)</a></li><li><a href="https://www.crazygames.com/game/evowarsio">EvoWars.io</a></li><li><a href="https://www.crazygames.com/game/merc-zone">Merc Zone</a></li><li><a href="https://www.crazygames.com/game/minigiants-io">MiniGiants.io</a></li><li><a href="https://www.crazygames.com/game/voxiom-io">Voxiom.io</a></li></ol><h3>What are the best .io Games to play on mobile phones and tablets?</h3><ol><li><a href="https://www.crazygames.com/game/bloxdhop-io">Bloxd.io</a></li><li><a href="https://www.crazygames.com/game/flyordieio">EvoWorld.io (FlyOrDie.io)</a></li><li><a href="https://www.crazygames.com/game/evowarsio">EvoWars.io</a></li><li><a href="https://www.crazygames.com/game/minigiants-io">MiniGiants.io</a></li><li><a href="https://www.crazygames.com/game/territorial-io">Territorial.io</a></li></ol><h3>What are .io Games?</h3><div><p>IO games are real-time online games you can play in your web browser for free. The most common theme among .io games is online multiplayer. Besides that, these g ...
# 39 urls collected
# ['https://www.crazygames.com.br/',
#  'http://www.crazygames.com/',
#  'https://www.crazygames.com/',
#  'https://www.crazygames.hu/',
#  'https://www.crazygames.fr/',
#  'https://fonts.googleapis.com/',
#  'https://www.crazygames.fi/',
#  'https://fonts.gstatic.com/',
#  'https://workers.crazygames.com/',
#  'https://builds.crazygames.com/',
#  'https://videos.crazygames.com/',
#  'https://www.crazygames.no/',
#  'https://www.googletagmanager.com/',
#  'https://de.crazygames.com/',
#  'https://www.crazygames.dk/',
#  'https://www.crazygames.co.id/',
#  'https://gr.crazygames.com/',
#  'https://files.crazygames.com/',
#  'https://www.crazygames.nl/',
#  'https://www.googletagservices.com/',
#  'https://th.crazygames.com/',
#  'https://cdn.iubenda.com/',
#  'https://ar.crazygames.com/',
#  'http://www.w3.org/',
#  'https://www.1001juegos.com/',
#  'https://www.crazygames.ru/',
#  'https://www.crazygames.cz/',
#  'https://www.crazygames.com.ua/',
#  'https://www.crazygames.ro/',
#  'https://www.crazygames.com.vn/',
#  'https://c2b85208be5148c1a11249beed30536c@sentry.io/',
#  'https://images.crazygames.com/',
#  'https://2caddb098d1c43b2a5e9eeb2e3475c9e@sentry.io/',
#  'https://www.crazygames.se/',
#  'https://it.crazygames.com/',
#  'https://crazygames.recruitee.com/',
#  'https://tr.crazygames.com/',
#  'https://www.trustpilot.com/',
#  'https://pl.crazygames.com/']
