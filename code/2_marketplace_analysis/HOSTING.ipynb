# %%
import pandas as pd

# %%
data = pd.read_csv('res_hosting.csv')

# %%
data
# Out:
#                    #inspected_URL                landing_URL self_hosted
# 0     https://www.puzzles.msn.com                       None     unknown
# 1           http://games2rule.com                       None     unknown
# 2          http://puzzles.msn.com   https://puzzles.msn.com/       False
# 3      http://www.puzzles.msn.com                       None       False
# 4       http://www.games2rule.com                       None       False
# ...                           ...                        ...         ...
# 3770      http://games.tochka.net  https://games.tochka.net/       False
# 3771          https://miniclip.ro                       None       False
# 3772      https://www.miniclip.ro                       None       False
# 3773           http://miniclip.ro                       None       False
# 3774       http://www.miniclip.ro                       None       False
#
# [3775 rows x 3 columns]

# %%
data[data['self_hosted']!='False']
# Out:
#                           #inspected_URL                      landing_URL  \
# 0            https://www.puzzles.msn.com                             None
# 1                  http://games2rule.com                             None
# 1083                  http://gamesweb.nl              http://gamesweb.nl/
# 1204          https://www.es.games68.com                             None
# 1325                      #inspected_URL                      landing_URL
# 1326          https://www.es.games68.com                             None
# 1447                      #inspected_URL                      landing_URL
# 1448          https://www.es.games68.com                             None
# 1759              http://www.game-ac.com             https://game-ac.com/
# 1843           https://www.it.goobix.com                             None
# 2177                    http://p-game.jp               https://p-game.jp/
# 2178                http://www.p-game.jp           https://www.p-game.jp/
# ...

# %%
# We expands the domain name with the "http://", "https://", "http://www.", "https://www." prefixes and check 
# if it is sef-hosted or not. In generl we had 3773 items to check.
# Here are the results:

\begin{tabular}{ll}
\toprule
            Hosting                                   \\
\midrule
            Number of self-hosted websites :  & 0\\
            Number of not self-hosted websites :  & 3730\\
            Number of websites about which we can`t find information:  & 43\\
\bottomrule
\end{tabular}
# Out:
#   File "<ipython-input-7-33564ec27c3b>", line 1
#     We expands the domain name with the "http://", "https://", "http://www.", "https://www." prefixes and check if it is sef-hosted or not. In generl we had 3773 items to check.
#        ^
# SyntaxError: invalid syntax
