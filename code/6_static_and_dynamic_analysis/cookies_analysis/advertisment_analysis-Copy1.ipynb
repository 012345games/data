# %%
import pandas as pd

# %%
MPS = ['y8', 'crazygames', 'coolmathgames', 'kibagames', 'vseigru', 'ufreegames', 'itch',
      'fukgames', 'addictinggames', 'webgameapp', 'mousebreaker', 'poki', 'bestgames',
      'babygames', 'yad', 'miniclip', 'iogame','spiels','friv','yupi','gameflare','yourgames']

# %%
MP = 'y8'

# %%
# input file
df = pd.read_csv(f"cookie_category_vs_persistent_analysis/{MP}.csv")
temp = df[~df["domain"].str.contains(MP) == True]
temp
temp2 = temp[temp["explicitly_set_by_host"].str.contains('Targeting/Advertising') == True]
temp2
# taking out sld domain
listy = temp2['domain'].to_list()
listy
# Out:
#             cookie                domain       expires  session  \
# 3             ouid          .addthis.com  1.693440e+09    False
# 10             uvc          .addthis.com  1.693958e+09    False
# 17             loc          .addthis.com  1.693958e+09    False
# 29      ljt_reader            .lijit.com  1.686711e+09    False
# 30               V       .contextweb.com  1.686279e+09    False
# ...            ...                   ...           ...      ...
# 588705       TDCPM           .adsrvr.org  1.683274e+09    False
# 588711      IDSYNC  .analytics.yahoo.com  1.683274e+09    False
# 588712           d       .quantserve.com  1.659514e+09    False
# 588713          mc       .quantserve.com  1.685952e+09    False
# 588716      CMRUM3      .casalemedia.com  1.683274e+09    False
#
#                                    explicitly_set_by_host
# 3       ['Social Media sharing tracking cookie.', 'The...
# 10      ['Tracks how often a user interacts with AddTh...
# 17      ['Stores the visitors geolocation to record lo...
# 29      ['Collects data related to reader interests, c...
# 30      ['Marketo tracking code. Tracks all individual...
# ...                                                   ...
# 588705  ['This domain is owned by TheTradeDesk. The ma...
# 588711  ['This cookie carries out information about ho...
# 588712  ['Yahoo HTTP Cookie', 'The main purpose of thi...
# 588713  ['This cookie is usually provided by Quantserv...
# 588716  ['These cookies are linked to advertising and ...
#
# [116955 rows x 5 columns]

# %%
# Out:
# ['.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.lijit.com',
#  '.contextweb.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.famobi.com',
#  '.lnk.to',
#  '.twitter.com',
#  '.lnk.to',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.bing.com',
#  '.linkedin.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.company-target.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.company-target.com',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.addthis.com',
#  '.rlcdn.com',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.adingo.jp',
#  '.pubmatic.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.adotmob.com',
#  '.casalemedia.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.linkedin.com',
#  '.mookie1.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.tapad.com',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.w55c.net',
#  '.bidr.io',
#  '.agkn.com',
#  '.casalemedia.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.youtube.com',
#  '.youtube.com',
#  '.youtube.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.dpm.demdex.net',
#  '.advertising.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.doubleclick.net',
#  '.agkn.com',
#  '.casalemedia.com',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.dressupwho.com',
#  '.rubiconproject.com',
#  '.pubmatic.com',
#  '.adsrvr.org',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.mookie1.com',
#  '.connectad.io',
#  '.mathtag.com',
#  '.adotmob.com',
#  '.tapad.com',
#  '.ambientdsp.com',
#  '.quantserve.com',
#  '.w55c.net',
#  '.w55c.net',
#  '.linksynergy.com',
#  '.pubmatic.com',
#  '.lijit.com',
#  '.omnitagjs.com',
#  '.adfarm1.adition.com',
#  '.smartadserver.com',
#  '.mathtag.com',
#  '.rlcdn.com',
#  '.linkedin.com',
#  '.analytics.yahoo.com',
#  '.bidr.io',
#  '.quantserve.com',
#  '.ctnsnet.com',
#  '.rfihub.com',
#  '.rfihub.com',
#  '.smartadserver.com',
#  '.smartadserver.com',
#  '.adsby.bidtheatre.com',
#  '.casalemedia.com',
#  '.tidaltv.com',
#  '.acuityplatform.com',
#  '.tribalfusion.com',
#  '.dressupwho.com',
#  'beacon.lynx.cognitivlabs.com',
#  '.dotomi.com',
#  '.contextweb.com',
#  '.adsrvr.org',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.bing.com',
#  '.linkedin.com',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.bidr.io',
#  '.tapad.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.smartadserver.com',
#  '.smartadserver.com',
#  '.smartadserver.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.bing.com',
#  '.doubleclick.net',
#  '.linkedin.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.tapad.com',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.bing.com',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.bing.com',
#  '.linkedin.com',
#  '.rfihub.com',
#  '.rfihub.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.gamedistribution.com',
#  '.pubmatic.com',
#  '.agkn.com',
#  '.pubmatic.com',
#  '.doubleclick.net',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.innovid.com',
#  '.casalemedia.com',
#  '.mookie1.com',
#  '.adingo.jp',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.bing.com',
#  '.linkedin.com',
#  '.mookie1.com',
#  '.tapad.com',
#  '.mathtag.com',
#  '.agkn.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.linkedin.com',
#  '.adsrvr.org',
#  '.rfihub.com',
#  '.rfihub.com',
#  '.casalemedia.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.mookie1.com',
#  '.bing.com',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.tapad.com',
#  '.adsrvr.org',
#  '.agkn.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.adsrvr.org',
#  '.doubleclick.net',
#  '.advertising.com',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.dressupwho.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.agkn.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  'pool.admedo.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  'pool.admedo.com',
#  '.casalemedia.com',
#  '.pubmatic.com',
#  '.adotmob.com',
#  '.mathtag.com',
#  '.smartadserver.com',
#  '.quantserve.com',
#  '.rubiconproject.com',
#  '.linkedin.com',
#  '.quantserve.com',
#  '.rlcdn.com',
#  '.ambientdsp.com',
#  '.w55c.net',
#  '.dotomi.com',
#  '.w55c.net',
#  '.linksynergy.com',
#  '.smartadserver.com',
#  '.smartadserver.com',
#  '.mookie1.com',
#  '.connectad.io',
#  '.pubmatic.com',
#  '.tapad.com',
#  '.lijit.com',
#  '.casalemedia.com',
#  '.dpm.demdex.net',
#  '.tribalfusion.com',
#  '.dressupwho.com',
#  '.adsrvr.org',
#  '.analytics.yahoo.com',
#  '.mathtag.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.mookie1.com',
#  '.analytics.yahoo.com',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.bidr.io',
#  '.tapad.com',
#  '.casalemedia.com',
#  '.agkn.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.linkedin.com',
#  '.tapad.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.mathtag.com',
#  '.bidr.io',
#  '.casalemedia.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.linkedin.com',
#  '.mookie1.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.tapad.com',
#  '.rlcdn.com',
#  '.analytics.yahoo.com',
#  '.mathtag.com',
#  '.casalemedia.com',
#  '.agkn.com',
#  '.linksynergy.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.7sgames.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.pubmatic.com',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.innovid.com',
#  '.mookie1.com',
#  '.adingo.jp',
#  '.pubmatic.com',
#  '.agkn.com',
#  '.e.dlx.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.rubiconproject.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.adingo.jp',
#  '.tapad.com',
#  '.bidr.io',
#  '.w55c.net',
#  '.rlcdn.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.linkedin.com',
#  '.bidr.io',
#  '.mathtag.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.linkedin.com',
#  '.mookie1.com',
#  '.tapad.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.w55c.net',
#  '.agkn.com',
#  '.casalemedia.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.linkedin.com',
#  '.tapad.com',
#  '.mookie1.com',
#  '.adsrvr.org',
#  '.bidr.io',
#  '.agkn.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.bing.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.linkedin.com',
#  '.adsrvr.org',
#  '.adotmob.com',
#  '.linksynergy.com',
#  '.rlcdn.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.company-target.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.company-target.com',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.gamedistribution.com',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.gamedistribution.com',
#  '.doubleclick.net',
#  '.pubmatic.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.analytics.yahoo.com',
#  '.mathtag.com',
#  '.linksynergy.com',
#  '.rlcdn.com',
#  '.w55c.net',
#  '.w55c.net',
#  '.ambientdsp.com',
#  '.pubmatic.com',
#  '.tribalfusion.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.bing.com',
#  '.linkedin.com',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.bing.com',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.tapad.com',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.dpm.demdex.net',
#  '.bidr.io',
#  '.casalemedia.com',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.gamedistribution.com',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  'pool.admedo.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  'pool.admedo.com',
#  '.doubleclick.net',
#  '.pubmatic.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.pubmatic.com',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.rlcdn.com',
#  '.analytics.yahoo.com',
#  '.mathtag.com',
#  '.linksynergy.com',
#  '.w55c.net',
#  '.w55c.net',
#  '.pubmatic.com',
#  '.ambientdsp.com',
#  '.tribalfusion.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.bing.com',
#  '.linkedin.com',
#  '.adsrvr.org',
#  '.w55c.net',
#  '.bluekai.com',
#  '.bluekai.com',
#  '.addthis.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  '.addthis.com',
#  '.addthis.com',
#  '.doubleclick.net',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.adsrvr.org',
#  '.linkedin.com',
#  '.casalemedia.com',
#  '.casalemedia.com',
#  '.bidr.io',
#  '.casalemedia.com',
#  '.adsrvr.org',
#  '.casalemedia.com',
#  '.mookie1.com',
#  '.tapad.com',
#  '.pubmatic.com',
#  '.pubmatic.com',
#  ...]

# %%
file1 = open("output_files/easylist_adult.txt", 'r')
Lines = file1.readlines()
Lines
for l in listy:
    for L in Lines:
        if l in L:
            print(l)
        else:
            pass

# %%
file1 = open("output_files/easylist_adversers.txt", 'r')
Lines = file1.readlines()
Lines
for l in listy:
    for L in Lines:
        if l in L:
            print(l)
        else:
            pass

# %%
file1 = open("output_files/easylist_adversers_popup.txt", 'r')
Lines = file1.readlines()
Lines
for l in listy:
    for L in Lines:
        if l in L:
            print(l)
        else:
            pass

# %%
file1 = open("output_files/fanboy_annoyance_thirdparty.txt", 'r')
Lines = file1.readlines()
Lines
for l in listy:
    for L in Lines:
        if l in L:
            print(l)
        else:
            pass
# Out:
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com
# .google.com

# %%
file1 = open("output_files/easylist_specific_fanboy.txt", 'r')
Lines = file1.readlines()
Lines
for l in listy:
    for L in Lines:
        if l in L:
            print(l)
        else:
            pass
# Out:
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com
# .twitter.com

# %%
tl = ['.com./$popup,domain=pornhub.com',
'|http*://*?$popup,third-party,domain=pornhub.com|redtube.com|tube8.com|youporn.com|youporngay.com',
'||clicknplay.to/api/$popup',
'||hotscopes.to/goways.php$popup',
'||icepbns.com^$popup,domain=iceporn.com',
'||livejasmin.com/pu/$popup',
'||videowood.tv/pop?$popup',
'||xtapes.to/out.php$popup',
'||xteen.name/xtn/$popup',
'! about:blank popups',
'/about:blank.*/$popup,domain=bitporno.com|iceporn.com|katestube.com|videowood.tv|xtapes.to',
'$popup,third-party,domain=asianclub.tv|porn-tube-club.com]']
for l in listy:
    for L in tl:
        if l in L:
            print(l)
        else:
            pass

# %% [markdown]
# # www.disconnect.me filters

# %%
# https://github.com/uBlock-LLC/uBlock/issues/1406
file1 = open("output_files/simple_ad.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass

from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
df_ht
# Out:
#           ad domain  count       perc
# 0      .addthis.com  43590  83.619482
# 5    .crwdcntrl.net   3255   6.244125
# 3     .pubmatic.com   2405   4.613555
# 2         .bing.com   1658   3.180571
# 4      .youtube.com    420   0.805694
# 1   .contextweb.com    391   0.750062
# 7       .google.com    342   0.656065
# 6      d.adroll.com     36   0.069059
# 8     .facebook.com     18   0.034530
# 9        .opera.com     12   0.023020
# 10     .weborama.fr      2   0.003837

# %%
#https://github.com/uBlock-LLC/uBlock/issues/1406
file1 = open("output_files/simple_tracking.txt", 'r')
Lines = file1.readlines()
Lines

lst = []
for l in listy:
    for L in Lines:
        if l in L:
            print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
df_ht

# %%
#https://github.com/uBlock-LLC/uBlock/issues/1406
#cite #https://disconnect.me/
file1 = open("output_files/simple_malvertising.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
df_ht
# Out:
#           ad domain  count       perc
# 0      .addthis.com  43590  83.619482
# 5    .crwdcntrl.net   3255   6.244125
# 3     .pubmatic.com   2405   4.613555
# 2         .bing.com   1658   3.180571
# 4      .youtube.com    420   0.805694
# 1   .contextweb.com    391   0.750062
# 7       .google.com    342   0.656065
# 6      d.adroll.com     36   0.069059
# 8     .facebook.com     18   0.034530
# 9        .opera.com     12   0.023020
# 10     .weborama.fr      2   0.003837

# %%
# https://zonefiles.io/compromised-domain-list/
file1 = open("output_files/compromised_domains.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
df_ht
# Out:
#             ad domain  count       perc
# 3     .quantserve.com   6514  32.158373
# 9      .crwdcntrl.net   3255  16.069313
# 4       .pubmatic.com   2405  11.873025
# 2          .rlcdn.com   1972   9.735387
# 5          .tapad.com   1575   7.775474
# 6           .w55c.net   1573   7.765600
# 7            .bidr.io    999   4.931872
# 16      .facebook.com    423   2.088270
# 1     .contextweb.com    391   1.930292
# 15         .adnxs.com    354   1.747630
# 0          .lijit.com    301   1.485979
# 11        .google.com    228   1.125592
# 8    .advertising.com    106   0.523302
# 13      .exelator.com     40   0.197472
# 10       d.adroll.com     36   0.177725
# 14      .iinet.net.au     32   0.157978
# 12  .imrworldwide.com     28   0.138231
# 17   .squarespace.com     18   0.088863
# 18         .opera.com      6   0.029621

# %%
# https://github.com/austinheap/sophos-xg-block-lists/blob/master/malware-domain-list.txt
file1 = open("output_files/malware-domain-list.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
df_ht
# Out:
# Empty DataFrame
# Columns: [ad domain, count, perc]
# Index: []

# %%
# https://unit42.paloaltonetworks.com/top-level-domains-cybercrime/
Lines = ['casino','xxx','poker','porn','bet','sex','sexy','adult','gq','webcam']

trimmed_list = []
for l in listy:
    try:
        l = l.split(".",1)[1].split(".",1)[1]
        if "." in l:
            l = l.split(".",1)[1]
            trimmed_list.append(l)
        else:
            trimmed_list.append(l)
    except:
        pass
trimmed_list = list(set(trimmed_list))
print(trimmed_list)
    

lst = []
for l in trimmed_list:
    for L in Lines:
            if L == l:
                print(l)
                lst.append(l)
            else:
                pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
df_ht
# Out:
# ['ai', 'com.au', 'gov.au', 'ba', 'co', 'io', 'museum', 'game', 'asia', 'kr', 'de', 'space', 'jp', 'ms', 'cloud', 'es', 'org', 'net', 'au', 'eu', 'online', 'shop', 'fun', 'com', 'nz', 'fr', 'cyou', 'games', 'to', 'ltd', 'edu.au', 'site', 'addthis.com', 'sg']
# Empty DataFrame
# Columns: [ad domain, count, perc]
# Index: []

# %%
# https://github.com/StevenBlack/hosts
(1) adware_plus_malware.txt
(2) fakenews.txt
(3) gambling.txt
(4) porn.txt
(5) social.txt

# %%
# https://github.com/StevenBlack/hosts
file1 = open("output_files/gambling.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
df_ht
# Out:
#                         ad domain    count       perc
# 7                .casalemedia.com  1941660  40.912289
# 0                    .addthis.com  1482060  31.228159
# 3                .doubleclick.net   586875  12.365913
# 8                     .adsrvr.org   171480   3.613217
# 24                 .crwdcntrl.net    94395   1.988976
# ..                            ...      ...        ...
# 101  .commercialrealestate.com.au        2   0.000042
# 92                     .acint.net        1   0.000021
# 94                     .sentry.io        1   0.000021
# 83                  my.rtmark.net        1   0.000021
# 80               www.talkable.com        1   0.000021
#
# [102 rows x 3 columns]

# %% [raw]
# https://www.semanticscholar.org/paper/Detecting-Malicious-URLs-Using-Lexical-Analysis-Mamun-Rathore/01bb00b24fb2bcf1d11748d0c39ba60367b4c264
#
# https://www.unb.ca/cic/datasets/index.html
#
# https://github.com/topics/malicious-url-detection
#
# I will have to use ML classification of th eentire URLs, instead of SLDs of advertisments I will use the dataset of requested and responded URLs after dealing with cookies piece
