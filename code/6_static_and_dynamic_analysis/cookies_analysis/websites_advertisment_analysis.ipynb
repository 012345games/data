# %%
import pandas as pd

# %%
# temp = pd.read_csv("../url_analysis/url_results.csv")
# temp.head(5)

# %%
MPS = ['y8', 'crazygames', 'coolmathgames', 'kibagames', 'vseigru', 'ufreegames', 'itch',
      'fukgames', 'addictinggames', 'webgameapp', 'mousebreaker', 'poki', 'bestgames',
      'babygames', 'yad', 'miniclip', 'iogame','spiels','friv','yupi','gameflare','yourgames']

# %%
MP = 'mousebreaker'

# %% [markdown]
# ### input file

# %%
# input file
df = pd.read_csv(f"cookie_category_vs_persistent_analysis/{MP}.csv")
temp = df[~df["domain"].str.contains(MP) == True]
temp
temp2 = temp[temp["explicitly_set_by_host"].str.contains('Targeting/Advertising') == True]
temp2
# taking out sld domain
listy = temp2['domain'].to_list()
listy
# Out:
# ['.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.gamedistribution.com',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.360yield.com',
#  '.bidswitch.net',
#  'pool.admedo.com',
#  '.360yield.com',
#  '.bidswitch.net',
#  'pool.admedo.com',
#  '.gamedistribution.com',
#  '.doubleclick.net',
#  '.pubmatic.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.pubmatic.com',
#  '.quantserve.com',
#  '.quantserve.com',
#  '.rlcdn.com',
#  '.bing.com',
#  '.analytics.yahoo.com',
#  '.mathtag.com',
#  '.linkedin.com',
#  '.linksynergy.com',
#  '.youtube.com',
#  '.w55c.net',
#  '.dotomi.com',
#  '.w55c.net',
#  '.pubmatic.com',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.crwdcntrl.net',
#  '.bidr.io',
#  '.thrtle.com',
#  '.quantserve.com',
#  '.advertising.com',
#  '.pubmatic.com',
#  '.adsrvr.org',
#  '.adsrvr.org',
#  '.rlcdn.com',
#  '.doubleclick.net',
#  '.w55c.net',
#  '.tribalfusion.com',
#  '.quantserve.com',
#  '.pubmatic.com',
#  '.analytics.yahoo.com',
# ...

# %% [markdown]
# # Easylist

# %% [markdown]
# ### 1

# %%
# https://github.com/easylist/easylist
file1 = open("output_files/easylist_adult.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            ls.append(lst)
        else:
            pass
lst

from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
df_ht
# Out:
# total domain: 0
# percentage of total unique ads found in list: 0.0
# Empty DataFrame
# Columns: [ad domain, count, perc]
# Index: []

# %% [markdown]
# ### 2

# %%
# https://github.com/easylist/easylist
file1 = open("output_files/easylist_adversers.txt", 'r')
Lines = file1.readlines()
Lines
lst =[]
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
lst

from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
df_ht
# Out:
# total domain: 0
# percentage of total unique ads found in list: 0.0
# Empty DataFrame
# Columns: [ad domain, count, perc]
# Index: []

# %% [markdown]
# ### 3

# %%
# https://github.com/easylist/easylist
file1 = open("output_files/easylist_adversers_popup.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
lst

from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
df_ht
# Out:
# total domain: 0
# percentage of total unique ads found in list: 0.0
# Empty DataFrame
# Columns: [ad domain, count, perc]
# Index: []

# %% [markdown]
# ### 4

# %%
# https://github.com/easylist/easylist
file1 = open("output_files/fanboy_annoyance_thirdparty.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
lst
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
df_ht
# Out:
# total domain: 0
# percentage of total unique ads found in list: 0.0
# Empty DataFrame
# Columns: [ad domain, count, perc]
# Index: []

# %% [markdown]
# ### 5

# %%
# https://github.com/easylist/easylist
file1 = open("output_files/easylist_specific_fanboy.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
lst


from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
df_ht
# Out:
# total domain: 0
# percentage of total unique ads found in list: 0.0
# Empty DataFrame
# Columns: [ad domain, count, perc]
# Index: []

# %%
0.09+0.135
# Out:
# 0.225

# %% [markdown]
# ### 5

# %%
tl = ['.com./$popup,domain=pornhub.com',
'|http*://*?$popup,third-party,domain=pornhub.com|redtube.com|tube8.com|youporn.com|youporngay.com',
'||clicknplay.to/api/$popup',
'||hotscopes.to/goways.php$popup',
'||icepbns.com^$popup,domain=iceporn.com',
'||livejasmin.com/pu/$popup',
'||videowood.tv/pop?$popup',
'||xtapes.to/out.php$popup',
'||xteen.name/xtn/$popup',
'! about:blank popups',
'/about:blank.*/$popup,domain=bitporno.com|iceporn.com|katestube.com|videowood.tv|xtapes.to',
'$popup,third-party,domain=asianclub.tv|porn-tube-club.com]']
for l in listy:
    for L in tl:
        if l in L:
            print(l)
        else:
            pass

# %% [markdown]
# # www.disconnect.me filters

# %% [markdown]
# ### 1

# %%
# https://github.com/uBlock-LLC/uBlock/issues/1406
file1 = open("output_files/simple_ad.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass

from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
df_ht
# Out:
# total domain: 8
# percentage of total unique ads found in list: 38.18770226537217
#                ad domain  count       perc
# 0         .crwdcntrl.net    516  36.440678
# 1          .pubmatic.com    381  26.906780
# 5             .opera.com    294  20.762712
# 4  .creative-serving.com    111   7.838983
# 2              .bing.com    108   7.627119
# 6           .addthis.com      3   0.211864
# 3           .youtube.com      2   0.141243
# 7        .contextweb.com      1   0.070621

# %% [markdown]
# ### 2

# %%
#https://github.com/uBlock-LLC/uBlock/issues/1406
file1 = open("output_files/simple_tracking.txt", 'r')
Lines = file1.readlines()
Lines

lst = []
for l in listy:
    for L in Lines:
        if l in L:
            print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
df_ht
# Out:
# total domain: 0
# percentage of total unique ads found in list: 0.0
# Empty DataFrame
# Columns: [ad domain, count, perc]
# Index: []

# %% [markdown]
# ### 3

# %%
#https://github.com/uBlock-LLC/uBlock/issues/1406
#cite #https://disconnect.me/
file1 = open("output_files/simple_malvertising.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
df_ht
# Out:
# total domain: 8
# percentage of total unique ads found in list: 38.18770226537217
#                ad domain  count       perc
# 0         .crwdcntrl.net    516  36.440678
# 1          .pubmatic.com    381  26.906780
# 5             .opera.com    294  20.762712
# 4  .creative-serving.com    111   7.838983
# 2              .bing.com    108   7.627119
# 6           .addthis.com      3   0.211864
# 3           .youtube.com      2   0.141243
# 7        .contextweb.com      1   0.070621

# %% [markdown]
# ### 4

# %%
# https://zonefiles.io/compromised-domain-list/
file1 = open("output_files/compromised_domains.txt", 'r')
Lines = file1.readlines()
Lines
lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
df_ht
# Out:
# total domain: 10
# percentage of total unique ads found in list: 59.681769147788565
#           ad domain  count       perc
# 0    .crwdcntrl.net    516  23.316765
# 2   .quantserve.com    508  22.955264
# 1     .pubmatic.com    381  17.216448
# 3        .rlcdn.com    254  11.477632
# 4         .w55c.net    246  11.116132
# 8        .opera.com    147   6.642567
# 6  .advertising.com     94   4.247628
# 5          .bidr.io     47   2.123814
# 7        .tapad.com     19   0.858563
# 9   .contextweb.com      1   0.045188

# %%
(44.5)+17.31
# Out:
# 61.81

# %% [markdown]
# # austingheap list

# %%
# # https://github.com/austinheap/sophos-xg-block-lists/blob/master/malware-domain-list.txt
# file1 = open("output_files/malware-domain-list.txt", 'r')
# Lines = file1.readlines()
# Lines
# lst = []
# for l in listy:
#     for L in Lines:
#         if l in L:
# #             print(l)
#             lst.append(l)
#         else:
#             pass
        
# from collections import Counter
# c = Counter(lst)
# c
# df_ht = pd.DataFrame(c, index=['count']).transpose()
# df_ht.index.rename('ad domain', inplace=True)
# df_ht.reset_index(inplace=True)
# df_ht
# df_ht = df_ht.sort_values(by = "count",ascending = False)
# df_ht
# sm = df_ht['count'].sum()
# l = []
# for index, row in df_ht.iterrows():
# #     print(row['count'])
# #     print(sm)
# #     print((row['count']/sm)*100)
#     l.append((row['count']/sm)*100)
# df_ht['perc'] = l
# print("total domain:", len(set(lst)))
# print("percentage of total unique ads found in list:", (len(lst)/len(listy))*100)
# df_ht

# %% [markdown]
# # top-level-domain cybersrime

# %%
# # https://unit42.paloaltonetworks.com/top-level-domains-cybercrime/
# Lines = ['casino','xxx','poker','porn','bet','sex','sexy','adult','gq','webcam']

# trimmed_list = []
# for l in listy:
#     try:
#         l = l.split(".",1)[1].split(".",1)[1]
#         if "." in l:
#             l = l.split(".",1)[1]
#             trimmed_list.append(l)
#         else:
#             trimmed_list.append(l)
#     except:
#         pass
# trimmed_list = list(set(trimmed_list))
# print(trimmed_list)
    

# lst = []
# for l in trimmed_list:
#     for L in Lines:
#             if L == l:
#                 print(l)
#                 lst.append(l)
#             else:
#                 pass
        
# from collections import Counter
# c = Counter(lst)
# c
# df_ht = pd.DataFrame(c, index=['count']).transpose()
# df_ht.index.rename('ad domain', inplace=True)
# df_ht.reset_index(inplace=True)
# df_ht
# df_ht = df_ht.sort_values(by = "count",ascending = False)
# df_ht
# sm = df_ht['count'].sum()
# l = []
# for index, row in df_ht.iterrows():
# #     print(row['count'])
# #     print(sm)
# #     print((row['count']/sm)*100)
#     l.append((row['count']/sm)*100)
# df_ht['perc'] = l
# print("total domain:", len(set(lst)))
# print("percentage of total unique ads found in list:", (len(listy)/len(lst))*100)
# df_ht

# %% [markdown]
# # stevenbalck lists

# %% [raw]
# # https://github.com/StevenBlack/hosts
# (1) adware_plus_malware.txt
# (2) fakenews.txt
# (3) gambling.txt
# (4) porn.txt
# (5) social.txt

# %% [markdown]
# # 1

# %%
# # https://github.com/StevenBlack/hosts
# file1 = open("output_files/adware_plus_malware.txt", 'r')
# Lines = file1.readlines()
# Lines

# lst = []
# for l in listy:
#     for L in Lines:
#         if l in L:
# #             print(l)
#             lst.append(l)
#         else:
#             pass
        
# from collections import Counter
# c = Counter(lst)
# c
# df_ht = pd.DataFrame(c, index=['count']).transpose()
# df_ht.index.rename('ad domain', inplace=True)
# df_ht.reset_index(inplace=True)
# df_ht
# df_ht = df_ht.sort_values(by = "count",ascending = False)
# df_ht
# sm = df_ht['count'].sum()
# l = []
# for index, row in df_ht.iterrows():
# #     print(row['count'])
# #     print(sm)
# #     print((row['count']/sm)*100)
#     l.append((row['count']/sm)*100)
# df_ht['perc'] = l
# print("total domain:", len(set(lst)))
# print("percentage of total unique ads found in list:", (len(listy)/len(lst))*100)
# df_ht

# %% [markdown]
# # 2

# %%
# # https://github.com/StevenBlack/hosts
# file1 = open("output_files/fakenews.txt", 'r')
# Lines = file1.readlines()
# Lines

# lst = []
# for l in listy:
#     for L in Lines:
#         if l in L:
# #             print(l)
#             lst.append(l)
#         else:
#             pass
        
# from collections import Counter
# c = Counter(lst)
# c
# df_ht = pd.DataFrame(c, index=['count']).transpose()
# df_ht.index.rename('ad domain', inplace=True)
# df_ht.reset_index(inplace=True)
# df_ht
# df_ht = df_ht.sort_values(by = "count",ascending = False)
# df_ht
# sm = df_ht['count'].sum()
# l = []
# for index, row in df_ht.iterrows():
# #     print(row['count'])
# #     print(sm)
# #     print((row['count']/sm)*100)
#     l.append((row['count']/sm)*100)
# df_ht['perc'] = l
# print("total domain:", len(set(lst)))
# print("percentage of total unique ads found in list:", (len(listy)/len(lst))*100)
# df_ht

# %% [markdown]
# # 3

# %%
# # https://github.com/StevenBlack/hosts
# file1 = open("output_files/gambling.txt", 'r')
# Lines = file1.readlines()
# Lines

# lst = []
# for l in listy:
#     for L in Lines:
#         if l in L:
# #             print(l)
#             lst.append(l)
#         else:
#             pass
        
# from collections import Counter
# c = Counter(lst)
# c
# df_ht = pd.DataFrame(c, index=['count']).transpose()
# df_ht.index.rename('ad domain', inplace=True)
# df_ht.reset_index(inplace=True)
# df_ht
# df_ht = df_ht.sort_values(by = "count",ascending = False)
# df_ht
# sm = df_ht['count'].sum()
# l = []
# for index, row in df_ht.iterrows():
# #     print(row['count'])
# #     print(sm)
# #     print((row['count']/sm)*100)
#     l.append((row['count']/sm)*100)
# df_ht['perc'] = l
# print("total domain:", len(set(lst)))
# print("percentage of total unique ads found in list:", (len(listy)/len(lst))*100)
# df_ht

# %% [markdown]
# # 4

# %%
# https://github.com/StevenBlack/hosts
file1 = open("output_files/porn.txt", 'r')
Lines = file1.readlines()
Lines

lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(listy)/len(lst))*100)
df_ht
# Out:
# total domain: 34
# percentage of total unique ads found in list: 5.32139320618246
#                 ad domain  count       perc
# 4        .doubleclick.net  16250  23.320561
# 0          .crwdcntrl.net  14964  21.475008
# 5           .pubmatic.com  11430  16.403324
# 6             .adsrvr.org   6096   8.748439
# 7         .quantserve.com   4064   5.832293
# 11           .mathtag.com   1792   2.571720
# 8              .rlcdn.com   1778   2.551628
# 30       .casalemedia.com   1771   2.541582
# 2          .bidswitch.net   1524   2.187110
# 15              .w55c.net   1476   2.118224
# 18       .advertising.com   1410   2.023507
# 13       .linksynergy.com   1008   1.446592
# 19      .tribalfusion.com    945   1.356180
# 21           .mookie1.com    918   1.317432
# 17               .bidr.io    799   1.146654
# 27          .impact-ad.jp    580   0.832365
# 10   .analytics.yahoo.com    508   0.729037
# 26     .gammaplatform.com    432   0.619968
# ...

# %% [markdown]
# # 5

# %%
# https://github.com/StevenBlack/hosts
file1 = open("output_files/social.txt", 'r')
Lines = file1.readlines()
Lines

lst = []
for l in listy:
    for L in Lines:
        if l in L:
#             print(l)
            lst.append(l)
        else:
            pass
        
from collections import Counter
c = Counter(lst)
c
df_ht = pd.DataFrame(c, index=['count']).transpose()
df_ht.index.rename('ad domain', inplace=True)
df_ht.reset_index(inplace=True)
df_ht
df_ht = df_ht.sort_values(by = "count",ascending = False)
df_ht
sm = df_ht['count'].sum()
l = []
for index, row in df_ht.iterrows():
#     print(row['count'])
#     print(sm)
#     print((row['count']/sm)*100)
    l.append((row['count']/sm)*100)
df_ht['perc'] = l
print("total domain:", len(set(lst)))
print("percentage of total unique ads found in list:", (len(listy)/len(lst))*100)
df_ht
# Out:
# total domain: 35
# percentage of total unique ads found in list: 4.60838656757227
#                 ad domain  count       perc
# 4        .doubleclick.net  16250  20.195869
# 0          .crwdcntrl.net  14964  18.597599
# 5           .pubmatic.com  11430  14.205463
# 12          .linkedin.com  11055  13.739405
# 6             .adsrvr.org   6096   7.576247
# 7         .quantserve.com   4064   5.050831
# 11           .mathtag.com   1792   2.227138
# 8              .rlcdn.com   1778   2.209739
# 31       .casalemedia.com   1771   2.201039
# 2          .bidswitch.net   1524   1.894062
# 15              .w55c.net   1476   1.834406
# 18       .advertising.com   1410   1.752380
# 13       .linksynergy.com   1008   1.252765
# 19      .tribalfusion.com    945   1.174467
# 21           .mookie1.com    918   1.140911
# 17               .bidr.io    799   0.993015
# 27          .impact-ad.jp    580   0.720837
# 10   .analytics.yahoo.com    508   0.631354
# ...

# %%
(2.46*4)+2.19
# Out:
# 12.03

# %% [markdown]
# # utils

# %% [raw]
# https://www.semanticscholar.org/paper/Detecting-Malicious-URLs-Using-Lexical-Analysis-Mamun-Rathore/01bb00b24fb2bcf1d11748d0c39ba60367b4c264
#
# https://www.unb.ca/cic/datasets/index.html
#
# https://github.com/topics/malicious-url-detection
#
# I will have to use ML classification of th eentire URLs, instead of SLDs of advertisments I will use the dataset of requested and responded URLs after dealing with cookies piece
