# %%
# https://www.cookieserve.com/ (for writing a piece on cookies)
# https://www.cookielawinfo.com/category/web-cookies/

# %%
#imports
import pandas as pd
import glob
import os
import json
import pickle
import tqdm

# %% [markdown]
# # 1-reading main PATH_COOKIES folder, reading cookie files per game and making clean csvs with details

# %%
# #functions
# def read_game_file(file_path):
#     with open(file_path, 'r') as f:
#         file_content = json.load(open(file_path))
#         return file_content
# #         f.close()
# def analyze_cookies(dct):
#     lst = []
#     for cookie in dct['cookies']:
#         d = {
#             'total_cookies': len(dct['cookies']),
#             'name': cookie['name'] if 'name' in cookie else None,
#             'value': cookie['value'] if 'name' in cookie else None,
#             'domain': cookie['domain'] if 'domain' in cookie else None,
#             'path': cookie['path']  if 'path' in cookie else None,
#             'secure': cookie['secure']  if 'secure' in cookie else None,
#             'expires': cookie['expires']  if 'expires' in cookie else None,
#             'size': cookie['size']  if 'expires' in cookie else None,
#             'httpOnly': cookie['httpOnly']  if 'httpOnly' in cookie else None,
#             'sameSite': cookie['sameSite']  if 'sameSite' in cookie else None,
#             'session': cookie['session']  if 'session' in cookie else None,
#             'priority':cookie['priority']  if 'priority' in cookie else None,
#             'sameParty': cookie['sameParty']  if 'sameParty' in cookie else None,
#             'sourceScheme': cookie['sourceScheme']  if 'sourceScheme' in cookie else None,
#             'sourcePort': cookie['sourcePort']  if 'sourcePort' in cookie else None}
#         lst.append(d)
#     return lst

# %% [markdown]
# # 2-writitng results in output_csvs_cookies_details

# %%
# #reading main PATH_COOKIES folder 
# # readin cookie files per game and making clean csvs with details
# in_path = '/data/iogames_data/PATH_COOKIES/'
# out_path = 'output_csvs_cookies_details/'
# # os.chdir(path)

# for file in os.listdir(in_path) :
#     game = file.split('.cookies',1)[0] 
#     if file.endswith(".cookies"): ## files from one marketplace can also be isolated "_poki.cookies"
#         print(file)
#         file_path = f'{in_path+file}'
# #         print(file_path)
#         game_cookies = read_game_file(file_path)
#         results = analyze_cookies(game_cookies)
#         df = pd.DataFrame(results)
#         df.to_csv(f'{out_path}/{game}_cookies_details.csv',index = False)

# %%
# per MP example

# MP = 'coolmathgames'
# mp_files = []
# files = glob.glob("output_csvs_cookies_details/*.*")
# for file in files:
#     if MP in file:
#         print(file)
#         mp_files.append(file)

# %%
# for f in fs:
#     try:
#         if "yourgames" in f:
#             print(f)
#             df = pd.read_csv(f)
#             print(df)
#         else:
#             pass
#     except:
#         pass
# #test code to see if yourgames had no cookies

# %% [markdown]
# # 3-Make a list of cookies from all MPs of the _cookie_detail.csvs

# %%
# # make a list of cookies from all MPs of the _cookie_detail.csvs stored in folder "output_csvs_cookies_details"

# import glob
# import pandas as pd

# cookie_names_list =[]
# failed_files = []
# fls = glob.glob("output_csvs_cookies_details/*.*")
# for f in fls:
#     try:
#         df = pd.read_csv(f)
#         cookie_names_list.extend(df['name'].to_list())
#     except:
#         failed_files.append(f)
#         pass

# %%
# print('total games investigated for cookies:',len(fls))

# %%
# # remove Nan from the cookie_name
# import math

# clean_cookie_names_list = []
# for c in cookie_names_list:
#     print(c)
#     if c == 'Nan':
#         pass
#     else:
#         clean_cookie_names_list.append(c)

# print("total number of cookies:", len(cookie_names_list))
# print("cookies after removing Nan:", len(clean_cookie_names_list))

# %% [markdown]
# # 4-Saving unique cookie list in cookies_list_for_cookiepedia.csv

# %%
# # save the unique cookie_list
# pd.DataFrame(list(set(clean_cookie_names_list))).to_csv("cookies_list_for_cookiepedia.csv",index =False)

# %%
# print(f"total cookies found in {len(fls)} games are:", len(clean_cookie_names_list))
# print(f"unique cookies found in {len(fls)} games are:", len(set(clean_cookie_names_list)))
# print(f"total games that did not have cookies {len(fls)} games are:", len(failed_files))

# %%
#look at the files that you could not process and move forward - those are empty files

# %% [markdown]
# # 5-Checking cookies with cookiepedia saving results in cookiepedia_output folder

# %%
# import requests
# from bs4 import BeautifulSoup

# cookiepedia_list = pd.read_csv('cookies_list_for_cookiepedia.csv')
# cookiepedia_list = cookiepedia_list['0'].to_list()
# cookiepedia_list
# for cookie in cookiepedia_list:
#         print(cookie)
#         cookie = cookie
#         URL = "https://cookiepedia.co.uk/cookies/" + str(cookie)
# #         print(URL)

#         #make request
#         headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'}
#         response = requests.get(URL, headers=headers)
#         # print(response.text)
#         html = response.text
#         soup = BeautifulSoup(html, "html.parser")
#         tags = soup.find_all(['p'])
#         t = []
#         for tag in tags[0:6]:
#             t.append(tag.get_text(separator=''))
#             try:
#     #             print(t)
#                 open_file = open(f'cookiepedia_output/{cookie}_cookiepedia_results.pkl', "wb")
#                 pickle.dump(t, open_file)
#                 open_file.close()
#             except:
#                 name = cookie[0:5]
#                 open_file = open(f'cookiepedia_output/{name}_cookiepedia_results.pkl', "wb")
#                 pickle.dump(t, open_file)
#                 open_file.close()

# %% [markdown]
# # 6- Reading cookiespedia results of unique cookies

# %%
# #read output_folder
# import glob
# import pandas as pd
# files = glob.glob("cookiepedia_output/*.*")
# files
# for file in files:
#     print(file)
#     print(pd.read_pickle(file))
#     break

# %% [markdown]
# # 7-Creating cookie dictionary

# %%
# L =[]
# for file in files:
#     try:
#     #     print(file)
#         res = pd.read_pickle(file)
#         if "Try entering" in res[0]:
#             status = 'not found'
#             d= {"cookie":file.split("/",1)[1].split("_cookiepedia",1)[0],
#                 "status":status,
#                 "generic_name": 'not_found',
#                 "purpose":'not_found',
#                 "details":'not_found',
#                 "found_#website":'not_found',
#                 "explicitly_set_by_host":res,
#                 "found_as_firstpartycookie":"not_found",
#                 "found_as_thirdpartycookie":"not_found",
#                 "found_as_persisitentcookie":"not_found",
#                 "life_span_of_persistent":"not_found"}
#             L.append(d)
#         elif "There is not yet any general" in res[0]:
# #             print(res[0])
#             status = 'not found'
#             d= {"cookie":file.split("/",1)[1].split("_cookiepedia",1)[0],
#                 "status":status,
#                "generic_name": 'not_found',
#                "purpose":'not_found',
#                 "details":'not_found',
#                "found_#website":'not_found',
#                "explicitly_set_by_host":res,
#                 "found_as_firstpartycookie":"not_found",
#                 "found_as_thirdpartycookie":"not_found",
#                 "found_as_persisitentcookie":"not_found",
#                 "life_span_of_persistent":"not_found"}
#             L.append(d)
#         elif "This search has identified" in res[0]:
# #             print(res)
#             status = 'found'
#             d= {"cookie":file.split("/",1)[1].split("_cookiepedia",1)[0],
#                 "status":status,
#                "generic_name":res[0][74:-91],
#                 "purpose":res[2][36:],
#                 "details":res[1],
#                "found_#website":test[3].split("found on ",1)[1].split(" website",1)[0],
#                "explicitly_set_by_host":test[3].split("set by ",1)[1].split(" host",1)[0],
#                 "found_as_firstpartycookie":test[4].split(" cookie on ",1)[1].split(" websites",1)[0],
#                 "found_as_thirdpartycookie":test[4].split(" Third Party cookie on ",1)[1].split(" websites",1)[0],
#                 "found_as_persisitentcookie":test[5].split(" Persistent cookie on ",1)[1].split(" websites",1)[0],
#                 "life_span_of_persistent":test[5].split(" span of ",1)[1].split(" days",1)[0]
#                }
#             L.append(d)
#         else:
#             print(res)
#             status = 'found'
#             d= {"cookie":file.split("/",1)[1].split("_cookiepedia",1)[0],
#                 "status":status,
#                "generic_name": 'not_found',
#                 "purpose":'not_found',
#                 "details":'not_found',
#                "found_#website":'not_found',
#                "explicitly_set_by_host":res,
#                 "found_as_firstpartycookie":"not_found",
#                 "found_as_thirdpartycookie":"not_found",
#                 "found_as_persisitentcookie":"not_found",
#                 "life_span_of_persistent":"not_found"
#                }
#             L.append(d)
#     except:
#         pass
# pd.DataFrame(L).sort_values('status').to_csv("cookies_dictionary.csv",index=False)

# %% [markdown]
# # 8- Read cookie dictionary and match the cookies with games

# %%
# df = pd.read_csv("cookies_dictionary.csv")
# not_found_cookies = df[df['status'] == "not found"]['cookie'].to_list() # find somewhere else
# found_cookies = df[df['status'] == "found"]['cookie'].to_list() # find find in games and report on marketplace leveel

# len(df)

# %% [markdown]
# # 9- Reading games and counting hits in blacklists and cookiepedia

# %%
#https://datatracker.ietf.org/doc/html/draft-west-first-party-cookies
# https://chromedevtools.github.io/devtools-protocol/tot/Network/#type-Cookie

# %%
# def check_cookiepedia_dict(cookie_name_list):
#     dct = pd.read_csv("cookies_dictionary.csv")
#     return(list(set(cookie_name_list) & set(dct['cookie'].tolist())))
# def check_easylist(cookie_name_list):
#     lines = open("easylist.txt").read().splitlines()
#     return(list(set(cookie_name_list) & set(lines)))
# def check_easyprivacylist(cookie_name_list):
#     lines = open("easyprivacylist.txt").read().splitlines()
#     return(list(set(cookie_name_list) & set(lines)))
# def check_easycookielist(cookie_name_list):
#     lines = open("easylist_cookielist.txt").read().splitlines()
#     return(list(set(cookie_name_list) & set(lines)))
# def mp_checker(file_path):
#     if "yupi" in file_path:
#         mp = 'yupi.io'
#     if "yourgames" in file_path:
#         mp = 'yourgames.io'
#     if "mousebreaker" in file_path:
#         mp = "mousebreaker.com"
#     if "bestgames" in file_path:
#         mp = "bestgames.com"
#     if "yad" in file_path:
#         mp = "yad.com"
#     if "babygames" in file_path:
#         mp = "babygames.com"
#     if  "iogame" in file_path:
#         mp = "iogame.app"
#     if "friv" in file_path:
#         mp = "friv.com"
#     if "webgameapp" in file_path:
#         mp = "webgameapp.com"
#     if "poki" in file_path:
#         mp = "poki.com"
#     if "ufreegames" in file_path:
#         mp = "ufreegames.com"
#     if "miniclip" in file_path:
#         mp = "miniclip.com"
#     if "coolmathgames" in file_path:
#         mp = "coolmathgames.com"
#     if "kibagames" in file_path:
#         mp = "kibagames.com"
#     if "spiels" in file_path:
#         mp = "spiels.at"
#     if "addictinggames" in file_path:
#         mp = "addictinggames.com"
#     if "crazygames" in file_path:
#         mp = "crazygames.com"
#     if "vseigru" in file_path:
#         mp = "vseigru.net"
#     if "fukgames" in file_path:
#         mp = "fukgames.com"
#     if "y8" in file_path:
#         mp = "y8.com"
#     if "itch" in file_path:
#         mp = "itch.io"
#     return(mp)

# %%
# import glob
# import tqdm
# files = glob.glob("output_csvs_cookies_details/*.*")
# L = []
# for file in tqdm.tqdm(files[:]):
#     try:
#     #     print(file)
#         game = file.split("/",1)[1].split("_cookies",1)[0]
# #         mp = file.split("/",1)[1].split("_cookies",1)[0].split("_")[-1]
#         mp = mp_checker(file)
#         res = pd.read_csv(file)
#         #1
#         cp_r = check_cookiepedia_dict(res['name'].to_list())
#         #2
#         el_ck_r = check_easylist(res['name'])
#         el_dmn_r = check_easylist(res['domain'])
#         #3
#         epl_ck_r = check_easyprivacylist(res['name'])
#         epl_dmn_r = check_easyprivacylist(res['domain'])
#         #4
#         ec_ck_r = check_easycookielist(res['name'])
#         ec_dmn_r = check_easylist(res['domain'])                              

#         d = {"mp":mp,"game":game,
#             "cookies_cookiepedia":cp_r,"#cookiepedia_hits":len(cp_r),
#             "cookies_easylist":el_ck_r,"#cookies_easylist_hits":len(el_ck_r),
#             "domains_easylist":el_dmn_r,"#domains_easylist_hits":len(el_dmn_r),
#             "cookies_easyprivacylist":epl_ck_r,"#cookies_easyprivacylist_hits":len(epl_ck_r),
#             "domains_easyprivacylist":epl_dmn_r,"#domains_easyprivacylist_hits":len(epl_dmn_r),
#             "cookies_easycookielist":ec_ck_r,"#cookies_easycookielist_hits":len(ec_ck_r),
#             "domains_easycookielist":ec_dmn_r,"#domains_easycookielist_hits":len(ec_dmn_r)}
#         L.append(d)
#     #     print(res)
#     except:
#         pass
# pd.DataFrame(L).to_csv("cookies_results.csv",index = False)

# %% [markdown]
# # read "cookies_result.csv" and "cookie_dictionary.csv" and plot to show how many cookies per MP was found on cookiepedia.

# %%
# cookiepedia_res = pd.read_csv("cookies_dictionary.csv")
# cookiepedia_res

# df_res = pd.read_csv("cookies_results.csv") # cookies saved for every game
# df_res.sort_values(by=['mp'], ascending=True)
# df_res

# for index,row in df_res.iterrows():
#     try:
#         mp = row['mp']
#         game = row['game']
#         eval(row['cookies_cookiepedia'])
#         cookiepedia_res[cookiepedia_res['cookie'].isin(eval(row['cookies_cookiepedia']))].to_csv(f"cookiepedia_results_to_plot/{mp}_{game}_cookies_found_in_cookiepedia.csv",index = False)
#     except:
#         pass

#done and saved

# %% [markdown]
# # results and plots

# %% [raw]
# # we have three types of results to report
# 1- stats of cookies found
# 2- cookiepedia results
# 3- actual cookie dictionaries that I saved

# %% [markdown]
# # RQ1, RQ2: stats of cookies found

# %%
# import glob
# import pandas as pd

# %%
# def mp_checker(file_path):
    
#     if "yupi" in file_path:
#         mp = 'yupi.io'
#     elif "yourgames" in file_path:
#         mp = 'yourgames.io'
#     elif "mousebreaker" in file_path:
#         mp = "mousebreaker.com"
#     elif "bestgames" in file_path:
#         mp = "bestgames.com"
#     elif "yad" in file_path:
#         mp = "yad.com"
#     elif "babygames" in file_path:
#         mp = "babygames.com"
#     elif  "iogame" in file_path:
#         mp = "iogame.app"
#     elif "friv" in file_path:
#         mp = "friv.com"
#     elif "webgameapp" in file_path:
#         mp = "webgameapp.com"
#     elif "poki" in file_path:
#         mp = "poki.com"
#     elif "gameflare" in file_path:
#         mp = "gameflare.com"
#     elif "ufreegames" in file_path:
#         mp = "ufreegames.com"
#     elif "miniclip" in file_path:
#         mp = "miniclip.com"
#     elif "coolmathgames" in file_path:
#         mp = "coolmathgames.com"
#     elif "kibagames" in file_path:
#         mp = "kibagames.com"
#     elif "spiels" in file_path:
#         mp = "spiels.at"
#     elif "addictinggames" in file_path:
#         mp = "addictinggames.com"
#     elif "crazygames" in file_path:
#         mp = "crazygames.com"
#     elif "vseigru" in file_path:
#         mp = "vseigru.net"
#     elif "_fukgames_" in file_path:
#         mp = "fukgames.com"
#     elif "_y8_" in file_path:
#         mp = "y8.com"
#     elif "_itch_" in file_path:
#         mp = "itch.io"
#     else:
#         mp = print("faulty string:", file_path)
#     return(mp)

# #1
# games = glob.glob("output_csvs_cookies_details/*")

# ck = []
# for game in games[:]:
#     ck.append(mp_checker(game))

# len(ck)

# from collections import Counter
# c = Counter(ck)
# df_ = pd.DataFrame(c, index=['#games with cookies']).transpose()
# df_.index.rename('MP', inplace=True)
# df_.reset_index(inplace=True)
# df_ = df_.sort_values(by = "#games with cookies",ascending = False, ignore_index = True)
# df_
# #2
# fs = glob.glob("output_csvs_cookies_details/*")
# LST = df_['MP'].tolist()

# L = []
# for i in LST[:]:
#     MP = i.split(".",1)[0]
#     print(MP)
#     ck = 0
#     for f in fs:
#         try:
#             if MP in f:
#                 df = pd.read_csv(f)
#                 ck+=len(df)
#             else:
#                 pass
#         except:
#             pass
#     d  = {"MP":i, "#total_cookies":ck}
#     L.append(d)
# # pd.DataFrame(L)
# temp_df = pd.DataFrame(L)
# temp_df
# #3
# df_plot = df_.merge(temp_df, on = 'MP')
# df_plot
# #change the yourgames.com to 0
# L = []
# for index,row in df_plot.iterrows():
#     if row['MP'] == "yourgames.io":
#         row['#games with cookies'] = 0
#     L.append(row)
# df_plot = pd.DataFrame(L)
# df_plot

# %%
# def ck_perc(MP, games_with_cookies):
    
#     if "yupi" in MP:
#         if games_with_cookies > 20:
#             perc = 100
#         else:
#             perc = (games_with_cookies/20)*100
#     elif "yourgames" in MP:
#         if games_with_cookies > 34:
#             perc = 100
#         else:
#             perc = (games_with_cookies/34)*100
#     elif "mousebreaker" in MP:
#         if games_with_cookies > 81:
#             perc = 100
#         else:
#             perc = (games_with_cookies/81)*100
#     elif "bestgames" in MP:
#         if games_with_cookies > 88:
#             perc = 100
#         else:
#             perc = (games_with_cookies/88)*100
#     elif "yad" in MP:
#         if games_with_cookies > 88:
#             perc = 100
#         else:
#             perc = (games_with_cookies/88)*100
#     elif "babygames" in MP:
#         if games_with_cookies > 88:
#             perc = 100
#         else:
#             perc = (games_with_cookies/88)*100
#     elif  "iogame" in MP:
#         if games_with_cookies > 239:
#             perc = 100
#         else:
#             perc = (games_with_cookies/239)*100
#     elif "friv" in MP:
#         if games_with_cookies > 345:
#             perc = 100
#         else:
#             perc = (games_with_cookies/345)*100
#     elif "webgameapp" in MP:
#         if games_with_cookies > 368:
#             perc = 100
#         else:
#             perc = (games_with_cookies/368)*100
#     elif "poki" in MP:
#         if games_with_cookies > 601:
#             perc = 100
#         else:
#             perc = (games_with_cookies/601)*100
#     elif "gameflare" in MP:
#         if games_with_cookies > 943:
#             perc = 100
#         else:
#             perc = (games_with_cookies/943)*100
#     elif "ufreegames" in MP:
#         if games_with_cookies > 1033:
#             perc = 100
#         else:
#             perc = (games_with_cookies/1033)*100
#     elif "miniclip" in MP:
#         if games_with_cookies > 1139:
#             perc = 100
#         else:
#             perc = (games_with_cookies/1139)*100
#     elif "coolmathgames" in MP:
#         if games_with_cookies > 1328:
#             perc = 100
#         else:
#             perc = (games_with_cookies/1328)*100
#     elif "kibagames" in MP:
#         if games_with_cookies > 2211:
#             perc = 100
#         else:
#             perc = (games_with_cookies/2211)*100
#     elif "spiels" in MP:
#         if games_with_cookies > 2673:
#             perc = 100
#         else:
#             perc = (games_with_cookies/2673)*100
#     elif "addictinggames" in MP:
#         if games_with_cookies > 3506:
#             perc = 100
#         else:
#             perc = (games_with_cookies/3506)*100
#     elif "crazygames" in MP:
#         if games_with_cookies > 7678:
#             perc = 100
#         else:
#             perc = (games_with_cookies/7678)*100
#     elif "vseigru" in MP:
#         if games_with_cookies > 9967:
#             perc = 100
#         else:
#             perc = (games_with_cookies/9967)*100
#     elif "fukgames_" in MP:
#         if games_with_cookies > 25496:
#             perc = 100
#         else:
#             perc = (games_with_cookies/25496)*100
#     elif "y8" in MP:
#         if games_with_cookies > 64029:
#             perc = 100
#         else:
#             perc = (games_with_cookies/64029)*100
#     elif "itch" in MP:
#         if games_with_cookies > 96604:
#             perc = 100
#         else:
#             perc = (games_with_cookies/96604)*100
#     else:
#         perc = 0
#     return(perc)

# LLL = []
# for index,row in df_plot.iterrows():
# #     print(row)
#     d = {"MP":row['MP'],"perc_games_with_cookies":ck_perc(row['MP'],row['#games with cookies'])}
#     LLL.append(d)
# #     break
# temp_perc = pd.DataFrame(LLL)
# temp_perc

# %%
# ck_perc(row['MP'],row['#games with cookies'])

# %%
# df_plot = df_plot.merge(temp_perc, on = 'MP')
# df_plot

# %% [markdown]
# # 2- cookiepedia results

# %%
# import glob
# import pandas as pd
# def mp_checker(file_path):
    
#     if "yupi" in file_path:
#         mp = 'yupi.io'
#     elif "yourgames" in file_path:
#         mp = 'yourgames.io'
#     elif "mousebreaker" in file_path:
#         mp = "mousebreaker.com"
#     elif "bestgames" in file_path:
#         mp = "bestgames.com"
#     elif "yad" in file_path:
#         mp = "yad.com"
#     elif "babygames" in file_path:
#         mp = "babygames.com"
#     elif  "iogame" in file_path:
#         mp = "iogame.app"
#     elif "friv" in file_path:
#         mp = "friv.com"
#     elif "webgameapp" in file_path:
#         mp = "webgameapp.com"
#     elif "poki" in file_path:
#         mp = "poki.com"
#     elif "gameflare" in file_path:
#         mp = "gameflare.com"
#     elif "ufreegames" in file_path:
#         mp = "ufreegames.com"
#     elif "miniclip" in file_path:
#         mp = "miniclip.com"
#     elif "coolmathgames" in file_path:
#         mp = "coolmathgames.com"
#     elif "kibagames" in file_path:
#         mp = "kibagames.com"
#     elif "spiels" in file_path:
#         mp = "spiels.at"
#     elif "addictinggames" in file_path:
#         mp = "addictinggames.com"
#     elif "crazygames" in file_path:
#         mp = "crazygames.com"
#     elif "vseigru" in file_path:
#         mp = "vseigru.net"
#     elif "fukgames" in file_path:
#         mp = "fukgames.com"
#     elif "y8" in file_path:
#         mp = "y8.com"
#     elif "itch" in file_path:
#         mp = "itch.io"
#     else:
#         mp = print("faulty string:", file_path)
#     return(mp)



# # get all games by vesigru.net


# LST = df_['MP'].tolist()

# Lx = []
# for item in LST[:]:
#     L = []
#     MP = item.split(".",1)[0]
#     print(MP)
#     files = glob.glob("cookiepedia_results_to_plot/*")
#     for file in files:
#         if MP in file:
#             #read results
#             _df = pd.read_csv(file)
#     #       # add the sus cookies to a global list of all sus cookies of the mp
#             for index,row in _df.iterrows():
#                 if eval(row['explicitly_set_by_host'])[0].startswith("There is not yet any general information about this cookie"):
#                     pass
#                 else:
#                     L.append(eval(row['explicitly_set_by_host']))

#     d = {"MP":item, "cookies in cookiepedia":L}
#     Lx.append(d)
# df_ckpdia = pd.DataFrame(Lx)

# %%
# Ll = []
# for index,row in df_ckpdia.iterrows():
#     Ll.append(len(row['cookies in cookiepedia']))
# df_ckpdia['# cookies in cookiepedia'] = Ll
# df_ckpdia

# %%
# _L = []
# for index, row in df_ckpdia.iterrows():
#     cats = []
#     for i in row['cookies in cookiepedia']:
#         try:
# #             print(i[1].split(":",1)[1])
#             cats.append(i[1].split(":",1)[1])
            
#         except:
#             pass
#     from collections import Counter
#     c = Counter(cats)
#     d = {"MP": row['MP'],"cats":c}
#     _L.append(d)
# df_cats = pd.DataFrame(_L)
# df_cats

# %%
# df_temp = df_plot.merge(df_ckpdia, on = "MP")
# df_temp

# %%
# df_plot_final = df_temp.merge(df_cats, on = "MP")
# df_plot_final.to_csv("output_files/final_cookie_stats.csv",index = False)
# df_plot_final

# %% [markdown]
# # Read results and plot

# %%
import glob
import pandas as pd
df = pd.read_csv("output_files/final_cookie_stats.csv")
df
# Out:
#                     MP  #games with cookies  #total_cookies  \
# 0               y8.com                18621          647987
# 1          vseigru.net                11180          133874
# 2       crazygames.com                10379          438243
# 3              itch.io                 6518           29028
# 4   addictinggames.com                 3493           17715
# 5            spiels.at                 2672            2672
# 6        kibagames.com                 2208          186457
# 7         fukgames.com                 1677           28656
# 8    coolmathgames.com                 1326          203806
# 9             poki.com                 1053            6732
# 10      ufreegames.com                 1042           29106
# 11      webgameapp.com                  734           17658
# 12             yad.com                  266            4567
# 13            friv.com                  254            1520
# 14        miniclip.com                  232            4526
# ...

# %%
from collections import Counter
ix = []
for index, row in df.iterrows():
#     print(dict(eval(row['cats'])))
    ix.append(dict(eval(row['cats'])))
df['cookie_cat'] = ix

# %%
df
# Out:
#                     MP  #games with cookies  #total_cookies  \
# 0               y8.com                18621          647987
# 1          vseigru.net                11180          133874
# 2       crazygames.com                10379          438243
# 3              itch.io                 6518           29028
# 4   addictinggames.com                 3493           17715
# 5            spiels.at                 2672            2672
# 6        kibagames.com                 2208          186457
# 7         fukgames.com                 1677           28656
# 8    coolmathgames.com                 1326          203806
# 9             poki.com                 1053            6732
# 10      ufreegames.com                 1042           29106
# 11      webgameapp.com                  734           17658
# 12             yad.com                  266            4567
# 13            friv.com                  254            1520
# 14        miniclip.com                  232            4526
# ...

# %%
# added this bit in the paper

# %%
df['cats'][20]
# Out:
# "Counter({' Targeting/Advertising': 39, ' Strictly Necessary': 9})"

# %%
df[['MP','#total_cookies','perc_games_with_cookies','cats']].sort_values(by = '#total_cookies',ascending = False)
# Out:
#                     MP  #total_cookies  perc_games_with_cookies  \
# 0               y8.com          647987                29.082135
# 2       crazygames.com          438243               100.000000
# 8    coolmathgames.com          203806                99.849398
# 6        kibagames.com          186457                99.864315
# 1          vseigru.net          133874               100.000000
# 10      ufreegames.com           29106               100.000000
# 3              itch.io           29028                 6.747133
# 7         fukgames.com           28656                 0.000000
# 4   addictinggames.com           17715                99.629207
# 11      webgameapp.com           17658               100.000000
# 17    mousebreaker.com           12475               100.000000
# 9             poki.com            6732               100.000000
# 16       bestgames.com            5481               100.000000
# 15       babygames.com            4962               100.000000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import matplotlib.ticker as mtick
from matplotlib.ticker import MaxNLocator
import seaborn as sns

sns.set_theme(style='white')
plt.rcParams["figure.figsize"] = (4,2.8)

data = df['perc_games_with_cookies'] # change this 1/4

plt.hist(data,bins = 22,color = 'tab:blue') #change this 2/4
# plt.xscale("log")


# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
# plt.gca().yaxis.set_minor_formatter(PercentFormatter(1))
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.gca().xaxis.set_major_formatter(PercentFormatter(100))

plt.xlabel('Percentage of games with cookies\n per website',fontsize=14) # change this 3/4
plt.ylabel('Count')

# plt.yscale('log')
plt.tick_params(axis='x', direction='out', length=4, bottom = True)
# plt.tick_params(axis='y', direction='out', length=4, left=True)

plt.grid()
plt.grid(b=True, which='major', color='grey', linestyle='-',alpha = 0.3)
plt.grid(b = True, which='minor', color='grey', alpha=0.05)
plt.minorticks_on()

plt.tick_params(axis='x', direction='out', length=4, bottom = True)
plt.tick_params(axis='y', direction='out', length=4, left=True)

plt.box(False)
plt.legend(frameon = False,fontsize = 12)
plt.tight_layout()


plt.savefig("./output_plots/perc_games_per_cookie.pdf")  # changee this 4/4
plt.show()
# Out:
# <ipython-input-8-188538463957>:30: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='grey', linestyle='-',alpha = 0.3)
# <ipython-input-8-188538463957>:31: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b = True, which='minor', color='grey', alpha=0.05)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#style
sns.set_theme(style='white')
plt.rcParams["figure.figsize"] = (5,2.8)

fig = sns.ecdfplot(data=df, x='#games with cookies',linewidth = 1.2,label = "#Games")
fig = sns.ecdfplot(data=df, x='#total_cookies',linewidth = 1.2,label = "#Cookies")
fig = sns.ecdfplot(data=df, x='# cookies in cookiepedia',linewidth = 1.2,label = "#Suspicious\ncookies")

plt.xscale("log")

plt.legend(fontsize = 11,frameon = False, bbox_to_anchor=(1,.5), ncol=1,)
plt.xlabel('Web game websites',fontsize=14)
plt.ylabel('CDF')

fig.tick_params(axis='x', direction='out', length=4, bottom = True)
fig.tick_params(axis='y', direction='out', length=4, left=True)

plt.grid()
plt.grid(b=True, which='major', color='grey', linestyle='-',alpha = 0.4)
plt.grid(which='minor', color='grey', alpha=0.05)
plt.minorticks_on()

plt.tick_params(axis='x', direction='out', length=4, bottom = True)
plt.tick_params(axis='y', direction='out', length=4, left=True)

plt.box(False)
plt.tight_layout()
plt.savefig("./output_plots/Number_of_games_with_cookies.pdf")
plt.show()
# Out:
# <ipython-input-11-b04a51404497>:19: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='grey', linestyle='-',alpha = 0.4)

# %%
#style
sns.set_theme(style='white')
plt.rcParams["figure.figsize"] = (4,2.8)

fig = sns.ecdfplot(data=df, x='#games with cookies',linewidth = 1.2,label = "")

plt.legend(fontsize = 11,frameon = False,loc='lower right')#, bbox_to_anchor=(1, 0.58), ncol=1,)
plt.xlabel('Number of games with cookies\nper marketplace',fontsize=14)
plt.ylabel('CDF')
fig.tick_params(axis='x', direction='out', length=4, bottom = True)
fig.tick_params(axis='y', direction='out', length=4, left=True)
plt.grid()
plt.grid(b=True, which='major', color='grey', linestyle='-',alpha = 0.4)
plt.grid(which='minor', color='black', alpha=0.1)
plt.minorticks_on()
plt.tick_params(axis='x', direction='out', length=4, bottom = True)
plt.tick_params(axis='y', direction='out', length=4, left=True)
plt.box(False)
plt.tight_layout()
plt.savefig("./output_plots/Number_of_games_with_cookies.pdf")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <ipython-input-12-c90f7cf841f4>:13: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='grey', linestyle='-',alpha = 0.4)

# %%
#style
sns.set_theme(style='white')
plt.rcParams["figure.figsize"] = (5,2.8)

fig = sns.ecdfplot(data=df_plot_final, x='#games with cookies',linewidth = 1.2,label = "#Games")
fig = sns.ecdfplot(data=df_plot_final, x='#total_cookies',linewidth = 1.2,label = "#Cookies")
fig = sns.ecdfplot(data=df_plot_final, x='# cookies in cookiepedia',linewidth = 1.2,label = "#Suspicious\ncookies")

plt.xscale("log")

plt.legend(fontsize = 11,frameon = False, bbox_to_anchor=(1,.5), ncol=1,)
plt.xlabel('Web game websites',fontsize=14)
plt.ylabel('CDF')

fig.tick_params(axis='x', direction='out', length=4, bottom = True)
fig.tick_params(axis='y', direction='out', length=4, left=True)

plt.grid()
plt.grid(b=True, which='major', color='grey', linestyle='-',alpha = 0.4)
plt.grid(which='minor', color='grey', alpha=0.05)
plt.minorticks_on()

plt.tick_params(axis='x', direction='out', length=4, bottom = True)
plt.tick_params(axis='y', direction='out', length=4, left=True)

plt.box(False)
plt.tight_layout()
plt.savefig("./output_plots/Number_of_games_with_cookies.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c298e23d6996> in <module>
#       3 plt.rcParams["figure.figsize"] = (5,2.8)
#       4
# ----> 5 fig = sns.ecdfplot(data=df_plot_final, x='#games with cookies',linewidth = 1.2,label = "#Games")
#       6 fig = sns.ecdfplot(data=df_plot_final, x='#total_cookies',linewidth = 1.2,label = "#Cookies")
#       7 fig = sns.ecdfplot(data=df_plot_final, x='# cookies in cookiepedia',linewidth = 1.2,label = "#Suspicious\ncookies")
#
# NameError: name 'df_plot_final' is not defined

# %%
#style
sns.set_theme(style='white')
plt.rcParams["figure.figsize"] = (4,2.8)

fig = sns.ecdfplot(data=df_plot_final, x='#games with cookies',linewidth = 1.2,label = "")

plt.legend(fontsize = 11,frameon = False,loc='lower right')#, bbox_to_anchor=(1, 0.58), ncol=1,)
plt.xlabel('Number of games with cookies\nper marketplace',fontsize=14)
plt.ylabel('CDF')
fig.tick_params(axis='x', direction='out', length=4, bottom = True)
fig.tick_params(axis='y', direction='out', length=4, left=True)
plt.grid()
plt.grid(b=True, which='major', color='grey', linestyle='-',alpha = 0.4)
plt.grid(which='minor', color='black', alpha=0.1)
plt.minorticks_on()
plt.tick_params(axis='x', direction='out', length=4, bottom = True)
plt.tick_params(axis='y', direction='out', length=4, left=True)
plt.box(False)
plt.tight_layout()
plt.savefig("./output_plots/Number_of_games_with_cookies.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4522e274cc28> in <module>
#       3 plt.rcParams["figure.figsize"] = (4,2.8)
#       4
# ----> 5 fig = sns.ecdfplot(data=df_plot_final, x='#games with cookies',linewidth = 1.2,label = "")
#       6
#       7 plt.legend(fontsize = 11,frameon = False,loc='lower right')#, bbox_to_anchor=(1, 0.58), ncol=1,)
#
# NameError: name 'df_plot_final' is not defined

# %%
# I added results as a table in the paper

# %% [markdown]
# # utils

# %%
# following cells processes cookies per mp basis- not using for now

# %%
# import requests
# from bs4 import BeautifulSoup

# #select a marketplace
# def cookiepedia(MP):
#     MP = MP
#     mp_files = []
#     files = glob.glob("output_csvs_cookies_details/*.*")
#     for file in files:
#         if MP in file:
#             print(file)
#             mp_files.append(file)

#     #find all the cookies in one game
#     mp_cookies = []
#     for f in mp_files:
#         try:
#     #     print(pd.read_csv(f)['name'])
#             mp_cookies.append(pd.read_csv(f)['name'])
#         except:
#             pass

#     for cookie in mp_cookies:
#         cookie = cookie
#         URL = "https://cookiepedia.co.uk/cookies/" + cookie
#         print(URL)

#         #make request
#         headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'}
#         response = requests.get(URL, headers=headers)
#         # print(response.text)
#         html = response.text
#         soup = BeautifulSoup(html, "html.parser")
#         tags = soup.find_all(['p'])
#         t = []
#         for tag in tags[0:6]:
#             t.append(tag.get_text(separator=''))
#             print(tag.get_text(separator=''))
#         #         t.to_pickle(f'{mp}_{game}_cookiepedia_results.pkl'

# %%
# MP = 'yad'
# mp_files = []
# files = glob.glob("output_csvs_cookies_analysis/*.*")

# for file in files:
#     D = []
#     if MP in file:
#         print('Game : ',file)
#         mp_files.append(file) #all files from a particular website
        
#         mp_cookies = []
#         for f in mp_files: #find all the cookies in one game
#             game = f.split("/",1)[1].split(".",)[0].split("_cookies",1)[0]
#             try:
#                 mp_cookies = pd.read_csv(f)['name'].to_list()
#             except:
#                 pass

#         for cookie in mp_cookies:
#             cookie = cookie
#             print("cookie :", cookie)
#             URL = "https://cookiepedia.co.uk/cookies/" + cookie
#             print("URL : ",URL)

#             #make request
#             headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'}
#             response = requests.get(URL, headers=headers)
#             # print(response.text)
#             html = response.text
#             soup = BeautifulSoup(html, "html.parser")
#             tags = soup.find_all(['p'])
#             text = []
#             for tag in tags:
#                 text.append(tag.get_text())
#             d= {"MP":MP,'game':game,"cookie":cookie,"cookiepedia_res":text}
#             D.append(d)
#         pd.DataFrame(D).to_csv(f'output_csvs_cookiepedia_analysis/{MP}_{game}_cookiepedia.csv',index = False)

# %%
# with open('output_csvs_cookiepedia_analysis/yad_Save-The-Girl_yad_iframe___gads_cookiepedia_results.pkl', 'rb') as f:
#     print(pickle.load(f))
